# %% [markdown]
# # load_ds: simple, medium, hard, each 5

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.34.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import json
from datasets import Dataset, concatenate_datasets

# %%
with open("/content/LeetCodeDataset-v0.1.0-test.jsonl", encoding="utf-8") as f:
# with open("LeetCodeDataset-v0.1.0-test.jsonl", encoding="utf-8") as f:
    rows = [json.loads(line) for line in f]

ds = Dataset.from_list(rows)
print(ds)
# Out:
# Dataset({
#     features: ['task_id', 'prompt', 'completion', 'entry_point', 'test', 'query', 'response', 'input_output', 'meta'],
#     num_rows: 175
# })

# %%
def first_k_by_difficulty(dataset, difficulty, k=5):
    """
    Return the first k rows whose meta['difficulty'] matches `difficulty`.
    """
    subset = dataset.filter(lambda ex: ex["meta"]["difficulty"] == difficulty)
    return subset.select(range(min(k, len(subset))))   # protects against < k rows

# %%
easy_ds   = first_k_by_difficulty(ds, "Easy",   k=5)
medium_ds = first_k_by_difficulty(ds, "Medium", k=5)
hard_ds   = first_k_by_difficulty(ds, "Hard",   k=5)
example_ds = concatenate_datasets([easy_ds.select([0]), medium_ds.select([0]), hard_ds.select([0])]) # serve as few shot examples
# Out:
# Filter:   0%|          | 0/175 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/175 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/175 [00:00<?, ? examples/s]

# %% [markdown]
# # load model

# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
if torch.backends.mps.is_built():
    device = "mps"
elif torch.backends.cuda.is_built():
    device = "cuda"
else:
    device = "cpu"

# %%
print(device)
# Out:
# cuda

# %%
MODEL_NAME = "bigcode/starcoder2-3b"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model     = AutoModelForCausalLM.from_pretrained(MODEL_NAME).to(device).eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/12.1G [00:00<?, ?B/s]

# %% [markdown]
# # INIT CODE GEN

# %%
from itertools import islice
from textwrap import dedent

import re

# %% [markdown]
# ### build few-shot part

# %%
ONE_PROMPT_BLOCK_TEMPLATE = """
<start>
<fim_prefix>
{prefix}
<fim_middle>
{middle}
<end>
""".strip()


TARGET_BLOCK_TEMPLATE = """
<start>
<fim_prefix>
{prefix}
<fim_middle>
""".strip() # no <end> so the model will generate right after <fim_middle>

# %%
def fewshot_row_to_block(q) -> str:
    examples = "\n".join(
        f"Input:  {p['input']}\nOutput: {p['output']}"
        for p in q["input_output"][:2] # get 2 expexted input/output
    )

    prefix = q["query"] + "\n\n"

    middle = q["completion"].strip()

    # assemble block
    return ONE_PROMPT_BLOCK_TEMPLATE.format(
        prefix = prefix,
        middle = middle
    )

# %%
few_shot_part = "\n\n".join(
    fewshot_row_to_block(r) for r in(example_ds)
)

# %%
print(few_shot_part)
# Out:
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>

# %% [markdown]
# ### build complete prompt

# %%
def make_prompt(
    few_shot_part: str,
    q        # one row from `ds`
             # formatter: row → str
) -> str:

    examples = "\n".join(
        f"Input:  {p['input']}\nOutput: {p['output']}"
        for p in q["input_output"][:2]
    )

    prefix = q["query"]

    target_part = TARGET_BLOCK_TEMPLATE.format(
        prefix=prefix,
    )

    return (
       "You are a Python programming assistant. "
        "Solve each new problem exactly as in previous examples. "
        "Do not output anything except the docstring and code that goes inside the provided "
        "class skeleton.\n"
        + few_shot_part
        + "\n\n"
        + target_part
        + "\n"
    )

def generate_solution (
    prompt: str,
    max_new_tokens: int = 2048,
) -> str:

    def strip_after_end(text: str) -> str:
        return text.split("<end>", 1)[0].rstrip()

    # encode
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    prompt_len = inputs.input_ids.shape[-1]

    # generate
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.2, # param from paper eval expermients
            top_p=0.95,
            do_sample=True,
        )

    # discard input
    gen_text = tokenizer.decode(output_ids[0][prompt_len:] )
    # discard after <end>
    return strip_after_end(gen_text)


# old
def generate_raw(
    prompt: str,
    tokenizer,
    model,
    device,
    max_new_tokens: int = 2048,
) -> str:
    """
    Encode → generate → decode → strip after <end>.
    Returns the model's raw textual response (still with both Solution classes).
    """
    def strip_after_end(text: str) -> str:
        return text.split("<end>", 1)[0].rstrip()

    # encode
    inputs = tokenizer(prompt, return_tensors="pt").to(device)

    # generate
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.2, # param from paper eval expermients
            top_p=0.95,
            do_sample=True,
            eos_token_id=tokenizer.convert_tokens_to_ids("<end>"),
        )

    # now output all, includng inputprompt, TODO: decide how to parse for target
    gen_text = tokenizer.decode(output_ids[0] )
    return gen_text


def extract_solution(text: str) -> str:
    """
    Return the slice that starts at the **second** (first is in query) occurrence of the token
    ``class Solution`` (or the first if there is only one) and ends at the
    **first ``<end>`` token** that appears after that point.

    Fallbacks
    ---------
    * If no ``class Solution`` exists, return the entire text.
    * If no ``<end>`` appears **after** the chosen class definition, return
      from the class definition to the end of the text.
    """
    # --- locate all "class Solution" hits ---------------------------------
    hits = list(re.finditer(r'\bclass\s+Solution\b', text))
    if not hits:                          # no Solution at all
        return text.strip()

    # pick second hit if it exists, otherwise the first
    start_pos = hits[1].start() if len(hits) >= 2 else hits[0].start()

    # --- look for the next "<end>" token after start_pos -------------------
    end_match = re.search(r'<end>', text[start_pos:])
    if end_match:
        end_pos = start_pos + end_match.start()
        return text[start_pos:end_pos].lstrip()
    else:                                 # no <end> after class
        return text[start_pos:].lstrip()

# %% [markdown]
# ### test w/ 4E+4M+4H
# note the first E/M/H is used as few shot example, so no test on them

# %% [markdown]
# #### easy2

# %%
print(easy_ds[1]['query'])
# Out:
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```

# %%
print(easy_ds[1]['query'])
print(easy_ds[1]['input_output'])
# Out:
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```
# [{'input': 'words = ["cd","ac","dc","ca","zz"]', 'output': '2'}, {'input': 'words = ["ab","ba","cc"]', 'output': '1'}, {'input': 'words = ["aa","ab"]', 'output': '0'}]

# %%
print(make_prompt(few_shot_part, easy_ds[1]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```
# <fim_middle>

# %%
raw_e2 = generate_raw(make_prompt(few_shot_part, easy_ds[1]), tokenizer, model, device)
print(raw_e2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
#         return sum(len(w) % 2 == 0 for w in words)
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array pairs where pairs[i] = [xi, yi] represents that the substring s[xi...yi] is a palindrome.
# Return the maximum number of distinct characters in s that can be removed to make all the substrings in pairs a palindrome.
# Note that the empty string is considered a palindrome.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, s: str, pairs: List[List[int]]) -> int:
# ```
#
#
#
# <end>

# %%
gen_e2 = generate_solution(make_prompt(few_shot_part, easy_ds[1]))
print(gen_e2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length

# %%
extracted_e2 = extract_solution(gen_e2)
print(extracted_e2)
# Out:
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length

# %% [markdown]
# #### easy 3

# %%
print(easy_ds[2]['query'])
# Out:
# A truck has two fuel tanks. You are given two integers, mainTank representing the fuel present in the main tank in liters and additionalTank representing the fuel present in the additional tank in liters.
# The truck has a mileage of 10 km per liter. Whenever 5 liters of fuel get used up in the main tank, if the additional tank has at least 1 liters of fuel, 1 liters of fuel will be transferred from the additional tank to the main tank.
# Return the maximum distance which can be traveled.
# Note: Injection from the additional tank is not continuous. It happens suddenly and immediately for every 5 liters consumed.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
# ```

# %%
print(make_prompt(few_shot_part, easy_ds[2]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# A truck has two fuel tanks. You are given two integers, mainTank representing the fuel present in the main tank in liters and additionalTank representing the fuel present in the additional tank in liters.
# The truck has a mileage of 10 km per liter. Whenever 5 liters of fuel get used up in the main tank, if the additional tank has at least 1 liters of fuel, 1 liters of fuel will be transferred from the additional tank to the main tank.
# Return the maximum distance which can be traveled.
# Note: Injection from the additional tank is not continuous. It happens suddenly and immediately for every 5 liters consumed.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
# ```
# <fim_middle>

# %%
raw_e3 = generate_raw(make_prompt(few_shot_part, easy_ds[2]), tokenizer, model, device)
print(raw_e3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# A truck has two fuel tanks. You are given two integers, mainTank representing the fuel present in the main tank in liters and additionalTank representing the fuel present in the additional tank in liters.
# The truck has a mileage of 10 km per liter. Whenever 5 liters of fuel get used up in the main tank, if the additional tank has at least 1 liters of fuel, 1 liters of fuel will be transferred from the additional tank to the main tank.
# Return the maximum distance which can be traveled.
# Note: Injection from the additional tank is not continuous. It happens suddenly and immediately for every 5 liters consumed.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
# ```
# <fim_middle>
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the sum of the squares of all equal subarrays of nums.
# A subarray is a contiguous, possibly empty sequence of

# %%
gen_e3 = generate_solution(make_prompt(few_shot_part, easy_ds[2]))
print(gen_e3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %%
extracted_e3 = extract_solution(gen_e3)
print(extracted_e3)
# Out:
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %% [markdown]
# #### easy4

# %%
print(easy_ds[3]['query'])
print(make_prompt(few_shot_part, easy_ds[3]))
# Out:
# You are given a 0-indexed integer array nums and an integer threshold.
# Find the length of the longest subarray of nums starting at index l and ending at index r (0 <= l <= r < nums.length) that satisfies the following conditions:
#
# nums[l] % 2 == 0
# For all indices i in the range [l, r - 1], nums[i] % 2 != nums[i + 1] % 2
# For all indices i in the range [l, r], nums[i] <= threshold
#
# Return an integer denoting the length of the longest such subarray.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
# ```
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer threshold.
# Find the length of the longest subarray of nums starting at index l and ending at index r (0 <= l <= r < nums.length) that satisfies the following conditions:
#
# nums[l] % 2 == 0
# For all indices i in the range [l, r - 1], nums[i] % 2 != nums[i + 1] % 2
# For all indices i in the range [l, r], nums[i] <= threshold
#
# Return an integer denoting the length of the longest such subarray.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
# ```
# <fim_middle>

# %%
print(generate_raw(make_prompt(few_shot_part, easy_ds[3]), tokenizer, model, device))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer threshold.
# Find the length of the longest subarray of nums starting at index l and ending at index r (0 <= l <= r < nums.length) that satisfies the following conditions:
#
# nums[l] % 2 == 0
# For all indices i in the range [l, r - 1], nums[i] % 2!= nums[i + 1] % 2
# For all indices i in the range [l, r], nums[i] <= threshold
#
# Return an integer denoting the length of the longest such subarray.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
# ```
# <fim_middle>
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 j = i + 1
#                 while j < n and nums[j] % 2!= nums[j - 1] % 2:
#                     j += 1
#                 ans = max(ans, j - i)
#                 i = j
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The score of a subarray is defined as the maximum value in the subarray.
# Return the maximum score of a subarray of nums.
# Note: A subarray is a contiguous non-

# %%
gen_e4 = generate_solution(make_prompt(few_shot_part, easy_ds[3]))
print(gen_e4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         n = len(nums)
#         dp = [0] * n
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 dp[i] = 1
#                 for j in range(i):
#                     if nums[j] % 2!= nums[i] % 2 and nums[j] <= threshold:
#                         dp[i] = max(dp[i], dp[j] + 1)
#         return max(dp)

# %%
extracted_e4 = extract_solution(gen_e4)
print(extracted_e4)
# Out:
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         n = len(nums)
#         dp = [0] * n
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 dp[i] = 1
#                 for j in range(i):
#                     if nums[j] % 2!= nums[i] % 2 and nums[j] <= threshold:
#                         dp[i] = max(dp[i], dp[j] + 1)
#         return max(dp)

# %% [markdown]
# #### easy 5

# %%
print(easy_ds[4]['query'])
print(make_prompt(few_shot_part, easy_ds[4]))
# Out:
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
# <fim_middle>

# %%
print(generate_raw(make_prompt(few_shot_part, easy_ds[4]), tokenizer, model, device))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return

# %%
gen_e5 = generate_solution(make_prompt(few_shot_part, easy_ds[4]))
print(gen_e5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %%
extracted_e5 = extract_solution(gen_e5)
print(extracted_e5)
# Out:
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %% [markdown]
# #### medium 2

# %%
print(medium_ds[1]['query'])
# Out:
# You are given an integer n denoting the total number of servers and a 2D 0-indexed integer array logs, where logs[i] = [server_id, time] denotes that the server with id server_id received a request at time time.
# You are also given an integer x and a 0-indexed integer array queries.
# Return a 0-indexed integer array arr of length queries.length where arr[i] represents the number of servers that did not receive any requests during the time interval [queries[i] - x, queries[i]].
# Note that the time intervals are inclusive.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
# ```

# %%
print(make_prompt(few_shot_part, medium_ds[1]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given an integer n denoting the total number of servers and a 2D 0-indexed integer array logs, where logs[i] = [server_id, time] denotes that the server with id server_id received a request at time time.
# You are also given an integer x and a 0-indexed integer array queries.
# Return a 0-indexed integer array arr of length queries.length where arr[i] represents the number of servers that did not receive any requests during the time interval [queries[i] - x, queries[i]].
# Note that the time intervals are inclusive.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
# ```
# <fim_middle>

# %%
raw_m1 = generate_raw(make_prompt(few_shot_part, medium_ds[1]), tokenizer, model, device)
print(raw_m1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given an integer n denoting the total number of servers and a 2D 0-indexed integer array logs, where logs[i] = [server_id, time] denotes that the server with id server_id received a request at time time.
# You are also given an integer x and a 0-indexed integer array queries.
# Return a 0-indexed integer array arr of length queries.length where arr[i] represents the number of servers that did not receive any requests during the time interval [queries[i] - x, queries[i]].
# Note that the time intervals are inclusive.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
# ```
# <fim_middle>
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
#         cnt = Counter()
#         for s, t in logs:
#             cnt[s] += 1
#         ans = [0] * len(queries)
#         for i, q in enumerate(queries):
#             ans[i] = n - cnt[q] - (q - x > 0)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums that are strictly greater than nums[i].
# Return the number of pairs of indices (i, j) such that i < j and nums[i] > nums[j].
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countLuckyPairs(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The value of the i-th element of nums is the number of elements in nums

# %%
gen_m2 = generate_solution(make_prompt(few_shot_part, medium_ds[1]))
print(gen_m2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
#         cnt = Counter()
#         for s, t in logs:
#             cnt[s] += 1
#         ans = [0] * len(queries)
#         for i, q in enumerate(queries):
#             ans[i] = n - cnt[q] - (q - x > 0)
#         return ans

# %%
extracted_m2 = extract_solution(gen_m2)
print(extracted_m2)
# Out:
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
#         cnt = Counter()
#         for s, t in logs:
#             cnt[s] += 1
#         ans = [0] * len(queries)
#         for i, q in enumerate(queries):
#             ans[i] = n - cnt[q] - (q - x > 0)
#         return ans

# %% [markdown]
# #### medium 3

# %%
print(medium_ds[2]['query'])
# Out:
# You are given a 0-indexed integer array nums representing the initial positions of some marbles. You are also given two 0-indexed integer arrays moveFrom and moveTo of equal length.
# Throughout moveFrom.length steps, you will change the positions of the marbles. On the ith step, you will move all marbles at position moveFrom[i] to position moveTo[i].
# After completing all the steps, return the sorted list of occupied positions.
# Notes:
#
# We call a position occupied if there is at least one marble in that position.
# There may be multiple marbles in a single position.
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
# ```

# %%
print(make_prompt(few_shot_part, medium_ds[2]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums representing the initial positions of some marbles. You are also given two 0-indexed integer arrays moveFrom and moveTo of equal length.
# Throughout moveFrom.length steps, you will change the positions of the marbles. On the ith step, you will move all marbles at position moveFrom[i] to position moveTo[i].
# After completing all the steps, return the sorted list of occupied positions.
# Notes:
#
# We call a position occupied if there is at least one marble in that position.
# There may be multiple marbles in a single position.
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
# ```
# <fim_middle>

# %%
raw_m3 = generate_raw(make_prompt(few_shot_part, medium_ds[2]), tokenizer, model, device)
print(raw_m3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums representing the initial positions of some marbles. You are also given two 0-indexed integer arrays moveFrom and moveTo of equal length.
# Throughout moveFrom.length steps, you will change the positions of the marbles. On the ith step, you will move all marbles at position moveFrom[i] to position moveTo[i].
# After completing all the steps, return the sorted list of occupied positions.
# Notes:
#
# We call a position occupied if there is at least one marble in that position.
# There may be multiple marbles in a single position.
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
# ```
# <fim_middle>
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
#         return sorted(set(nums + moveTo) - set(moveFrom))
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
#
# Find the sum of the elements in nums between indices lefti and righti (inclusive).
# If the sum is divisible by 2, then subtract 1 from it.
# Otherwise, subtract 2 from it.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumEvenAfterQueries(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given

# %%
gen_m3 = generate_solution(make_prompt(few_shot_part, medium_ds[2]))
print(gen_m3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %%
extracted_m3 = extract_solution(gen_m3)
print(extracted_m3)
# Out:
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans

# %% [markdown]
# #### medium 4

# %%
print(medium_ds[3]['query'])
print(make_prompt(few_shot_part, medium_ds[3]))
# Out:
# You are given an integer n and a 0-indexed 2D array queries where queries[i] = [typei, indexi, vali].
# Initially, there is a 0-indexed n x n matrix filled with 0's. For each query, you must apply one of the following changes:
#
# if typei == 0, set the values in the row with indexi to vali, overwriting any previous values.
# if typei == 1, set the values in the column with indexi to vali, overwriting any previous values.
#
# Return the sum of integers in the matrix after all queries are applied.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
# ```
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given an integer n and a 0-indexed 2D array queries where queries[i] = [typei, indexi, vali].
# Initially, there is a 0-indexed n x n matrix filled with 0's. For each query, you must apply one of the following changes:
#
# if typei == 0, set the values in the row with indexi to vali, overwriting any previous values.
# if typei == 1, set the values in the column with indexi to vali, overwriting any previous values.
#
# Return the sum of integers in the matrix after all queries are applied.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
# ```
# <fim_middle>

# %%
raw_m4 = generate_raw(make_prompt(few_shot_part, medium_ds[3]), tokenizer, model, device)
print(raw_m4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given an integer n and a 0-indexed 2D array queries where queries[i] = [typei, indexi, vali].
# Initially, there is a 0-indexed n x n matrix filled with 0's. For each query, you must apply one of the following changes:
#
# if typei == 0, set the values in the row with indexi to vali, overwriting any previous values.
# if typei == 1, set the values in the column with indexi to vali, overwriting any previous values.
#
# Return the sum of integers in the matrix after all queries are applied.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The array nums is called good if the following conditions are satisfied:
#
# nums contains no two adjacent equal elements.
# nums contains no two adjacent elements whose sum is divisible by 3.
# Return true if nums is good, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodArray(self, nums: List[int]) -> bool:
# ```

# %%
gen_m4 = generate_solution(make_prompt(few_shot_part, medium_ds[3]))
print(gen_m4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0

# %%
extracted_m4 = extract_solution(gen_m4)
print(extracted_m4)
# Out:
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0

# %% [markdown]
# #### medium5

# %%
print(medium_ds[4]['query'])
print(make_prompt(few_shot_part, medium_ds[4]))
# Out:
# You are given a positive integer array nums.
# Partition nums into two arrays, nums1 and nums2, such that:
#
# Each element of the array nums belongs to either the array nums1 or the array nums2.
# Both arrays are non-empty.
# The value of the partition is minimized.
#
# The value of the partition is |max(nums1) - min(nums2)|.
# Here, max(nums1) denotes the maximum element of the array nums1, and min(nums2) denotes the minimum element of the array nums2.
# Return the integer denoting the value of such partition.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
# ```
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a positive integer array nums.
# Partition nums into two arrays, nums1 and nums2, such that:
#
# Each element of the array nums belongs to either the array nums1 or the array nums2.
# Both arrays are non-empty.
# The value of the partition is minimized.
#
# The value of the partition is |max(nums1) - min(nums2)|.
# Here, max(nums1) denotes the maximum element of the array nums1, and min(nums2) denotes the minimum element of the array nums2.
# Return the integer denoting the value of such partition.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
# ```
# <fim_middle>

# %%
raw_m5 = generate_raw(make_prompt(few_shot_part, medium_ds[4]), tokenizer, model, device)
print(raw_m5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a positive integer array nums.
# Partition nums into two arrays, nums1 and nums2, such that:
#
# Each element of the array nums belongs to either the array nums1 or the array nums2.
# Both arrays are non-empty.
# The value of the partition is minimized.
#
# The value of the partition is |max(nums1) - min(nums2)|.
# Here, max(nums1) denotes the maximum element of the array nums1, and min(nums2) denotes the minimum element of the array nums2.
# Return the integer denoting the value of such partition.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return max(nums[i] - nums[~i] for i in range(len(nums) // 2))
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the number of good subarrays of nums.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def numberOfGoodSubarrays(self, nums: List[int]) -> int:

# %%
gen_m5 = generate_solution(make_prompt(few_shot_part, medium_ds[4]))
print(gen_m5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return max(nums[i] - nums[~i] for i in range(len(nums) // 2))

# %%
extracted_m5 = extract_solution(gen_m5)
print(extracted_m5)
# Out:
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return max(nums[i] - nums[~i] for i in range(len(nums) // 2))

# %% [markdown]
# #### hard2

# %%
print(hard_ds[1]['query'])
# Out:
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Given a 0-indexed integer array nums, return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```

# %%
print(make_prompt(few_shot_part, hard_ds[1]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Given a 0-indexed integer array nums, return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
# <fim_middle>

# %%
raw_h2 = generate_raw(make_prompt(few_shot_part, hard_ds[1]), tokenizer, model, device)
print(raw_h2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Given a 0-indexed integer array nums, return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
# <fim_middle>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums

# %%
gen_h2 = generate_solution(make_prompt(few_shot_part, hard_ds[1]))
print(gen_h2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             for j in range(i + 1, n):
#                 ans += (nums[j] - nums[i]) > 1
#         return ans

# %%
extracted_h2 = extract_solution(gen_h2)
print(extracted_h2)
# Out:
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             for j in range(i + 1, n):
#                 ans += (nums[j] - nums[i]) > 1
#         return ans

# %% [markdown]
# #### hard3

# %%
print(hard_ds[2]['query'])
# Out:
# Given a string s and an integer k, partition s into k substrings such that the letter changes needed to make each substring a semi-palindrome are minimized.
# Return the minimum number of letter changes required.
# A semi-palindrome is a special type of string that can be divided into palindromes based on a repeating pattern. To check if a string is a semi-palindrome:​
#
# Choose a positive divisor d of the string's length. d can range from 1 up to, but not including, the string's length. For a string of length 1, it does not have a valid divisor as per this definition, since the only divisor is its length, which is not allowed.
# For a given divisor d, divide the string into groups where each group contains characters from the string that follow a repeating pattern of length d. Specifically, the first group consists of characters at positions 1, 1 + d, 1 + 2d, and so on; the second group includes characters at positions 2, 2 + d, 2 + 2d, etc.
# The string is considered a semi-palindrome if each of these groups forms a palindrome.
#
# Consider the string "abcabc":
#
# The length of "abcabc" is 6. Valid divisors are 1, 2, and 3.
# For d = 1: The entire string "abcabc" forms one group. Not a palindrome.
# For d = 2:
#
# Group 1 (positions 1, 3, 5): "acb"
# Group 2 (positions 2, 4, 6): "bac"
# Neither group forms a palindrome.
#
#
# For d = 3:
#
# Group 1 (positions 1, 4): "aa"
# Group 2 (positions 2, 5): "bb"
# Group 3 (positions 3, 6): "cc"
# All groups form palindromes. Therefore, "abcabc" is a semi-palindrome.
#
#
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```

# %%
print(make_prompt(few_shot_part, hard_ds[2]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# Given a string s and an integer k, partition s into k substrings such that the letter changes needed to make each substring a semi-palindrome are minimized.
# Return the minimum number of letter changes required.
# A semi-palindrome is a special type of string that can be divided into palindromes based on a repeating pattern. To check if a string is a semi-palindrome:​
#
# Choose a positive divisor d of the string's length. d can range from 1 up to, but not including, the string's length. For a string of length 1, it does not have a valid divisor as per this definition, since the only divisor is its length, which is not allowed.
# For a given divisor d, divide the string into groups where each group contains characters from the string that follow a repeating pattern of length d. Specifically, the first group consists of characters at positions 1, 1 + d, 1 + 2d, and so on; the second group includes characters at positions 2, 2 + d, 2 + 2d, etc.
# The string is considered a semi-palindrome if each of these groups forms a palindrome.
#
# Consider the string "abcabc":
#
# The length of "abcabc" is 6. Valid divisors are 1, 2, and 3.
# For d = 1: The entire string "abcabc" forms one group. Not a palindrome.
# For d = 2:
#
# Group 1 (positions 1, 3, 5): "acb"
# Group 2 (positions 2, 4, 6): "bac"
# Neither group forms a palindrome.
#
#
# For d = 3:
#
# Group 1 (positions 1, 4): "aa"
# Group 2 (positions 2, 5): "bb"
# Group 3 (positions 3, 6): "cc"
# All groups form palindromes. Therefore, "abcabc" is a semi-palindrome.
#
#
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
# <fim_middle>

# %%
raw_h3 = generate_raw(make_prompt(few_shot_part, hard_ds[2]), tokenizer, model, device)
print(raw_h3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# Given a string s and an integer k, partition s into k substrings such that the letter changes needed to make each substring a semi-palindrome are minimized.
# Return the minimum number of letter changes required.
# A semi-palindrome is a special type of string that can be divided into palindromes based on a repeating pattern. To check if a string is a semi-palindrome:​
#
# Choose a positive divisor d of the string's length. d can range from 1 up to, but not including, the string's length. For a string of length 1, it does not have a valid divisor as per this definition, since the only divisor is its length, which is not allowed.
# For a given divisor d, divide the string into groups where each group contains characters from the string that follow a repeating pattern of length d. Specifically, the first group consists of characters at positions 1, 1 + d, 1 + 2d, and so on; the second group includes characters at positions 2, 2 + d, 2 + 2d, etc.
# The string is considered a semi-palindrome if each of these groups forms a palindrome.
#
# Consider the string "abcabc":
#
# The length of "abcabc" is 6. Valid divisors are 1, 2, and 3.
# For d = 1: The entire string "abcabc" forms one group. Not a palindrome.
# For d = 2:
#
# Group 1 (positions 1, 3, 5): "acb"
# Group 2 (positions 2, 4, 6): "bac"
# Neither group forms a palindrome.
#
#
# For d = 3:
#
# Group 1 (positions 1, 4): "aa"
# Group 2 (positions 2, 5): "bb"
# Group 3 (positions 3, 6): "cc"
# All groups form palindromes. Therefore, "abcabc" is a semi-palindrome.
#
#
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
# <fim_middle>
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
#         n = len(s)
#         dp = [[0] * 2 for _ in range(n)]
#         for i in range(n):
#             dp[i][0] = dp[i][1] = 1
#         for i in range(n):
#             if s[i] == "0":
#                 dp[i][0] = 0
#             else:
#                 dp[i][0] = dp[i - 1][0] + 1
#         for i in range(n - 1, -1, -1):
#             if s[i] == "1":
#                 dp[i][1] = 0
#             else:
#                 dp[i][1] = dp[i + 1][1] + 1
#         ans = n
#         for i in range(k):
#             ans = min(ans, dp[i][0] + dp[i + 1][1])
#         for i in range(n - k, n):
#             ans = min(ans, dp[i][0] + dp[i - 1][1])
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of only lowercase English letters.
# You are also given an integer k.
# In one operation, you can replace any character of s with any lowercase English letter.
# Return the minimum number of operations required such that the number of distinct substrings of s with length k or more is maximized.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumDistinctSubstring(self, s: str, k: int) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s consisting of lowercase English letters.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must find the maximum number of distinct characters in the substring s[lefti...righti] and return an array ans of length queries.length() such that ans[i] is the answer to the ith query.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharactersString(self, s: str, queries: List[List[int]]) -> List

# %%
gen_h3 = generate_solution(make_prompt(few_shot_part, hard_ds[2]))
print(gen_h3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class

# %%
extracted_h3 = extract_solution(gen_h3)
print(extracted_h3)
# Out:
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class

# %% [markdown]
# #### hard4

# %%
print(hard_ds[3]['query'])
# Out:
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```

# %%
print(make_prompt(few_shot_part, hard_ds[3]))
# Out:
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```
# <fim_middle>

# %%
raw_h4 = generate_raw(make_prompt(few_shot_part, hard_ds[3]), tokenizer, model, device)
print(raw_h4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         n = len(word)
#         ans = 0
#         for i in range(n):
#             for j in range(i + 1, n + 1):
#                 if word[i:j] not in forbidden:
#                     ans = max(ans, j - i)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3.
# Return the length of the longest good subarray of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestGoodSubarray(self, nums: List[int]) -> int:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed integer array nums.
# A subarray is called good if the sum of its elements is divisible by 3

# %%
gen_h4 = generate_solution(make_prompt(few_shot_part, hard_ds[3]))
print(gen_h4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         ans = 0
#         for i in range(len(word)):
#             for j in range(i + 1, len(word) + 1):
#                 if word[i:j] not in forbidden:
#                     ans = max(ans, j - i)
#         return ans

# %%
extracted_h4 = extract_solution(gen_h4)
print(extracted_h4)
# Out:
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         ans = 0
#         for i in range(len(word)):
#             for j in range(i + 1, len(word) + 1):
#                 if word[i:j] not in forbidden:
#                     ans = max(ans, j - i)
#         return ans

# %% [markdown]
# #### hard5

# %%
print(hard_ds[4]['query'])
print(make_prompt(few_shot_part, hard_ds[4]))
# Out:
# You are given a 0-indexed 2D integer array items of length n and an integer k.
# items[i] = [profiti, categoryi], where profiti and categoryi denote the profit and category of the ith item respectively.
# Let's define the elegance of a subsequence of items as total_profit + distinct_categories2, where total_profit is the sum of all profits in the subsequence, and distinct_categories is the number of distinct categories from all the categories in the selected subsequence.
# Your task is to find the maximum elegance from all subsequences of size k in items.
# Return an integer denoting the maximum elegance of a subsequence of items with size exactly k.
# Note: A subsequence of an array is a new array generated from the original array by deleting some elements (possibly none) without changing the remaining elements' relative order.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
# ```
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed 2D integer array items of length n and an integer k.
# items[i] = [profiti, categoryi], where profiti and categoryi denote the profit and category of the ith item respectively.
# Let's define the elegance of a subsequence of items as total_profit + distinct_categories2, where total_profit is the sum of all profits in the subsequence, and distinct_categories is the number of distinct categories from all the categories in the selected subsequence.
# Your task is to find the maximum elegance from all subsequences of size k in items.
# Return an integer denoting the maximum elegance of a subsequence of items with size exactly k.
# Note: A subsequence of an array is a new array generated from the original array by deleting some elements (possibly none) without changing the remaining elements' relative order.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
# ```
# <fim_middle>

# %%
raw_h5 = generate_raw(make_prompt(few_shot_part, hard_ds[3]), tokenizer, model, device)
print(raw_h5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# You are a Python programming assistant. Solve each new problem exactly as in previous examples. Do not output anything except the docstring and code that goes inside the provided class skeleton.
# <start>
# <fim_prefix>
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
# <end>
#
# <start>
# <fim_prefix>
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
#
#
# <fim_middle>
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
# <end>
#
# <start>
# <fim_prefix>
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
#
#
# <fim_middle>
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
# <end>
#
# <start>
# <fim_prefix>
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```
# <fim_middle>
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         n = len(word)
#         ans = 0
#         for i in range(n):
#             for j in range(i + 1, n + 1):
#                 if word[i:j] not in forbidden:
#                     ans = max(ans, j - i)
#         return ans
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[i] and has a length of queries[i] + 1.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctCharacters(self, s: str, queries: List[int]) -> List[int]:
# ```
#
#
#
# <end>
#
# <start>
#
# You are given a 0-indexed string s and a 0-indexed integer array queries.
# For the ith query, you need to find the maximum number of distinct characters in the substring of s that starts at queries[

# %%
gen_h5 = generate_solution(make_prompt(few_shot_part, hard_ds[4]))
print(gen_h5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans

# %%
extracted_h5 = extract_solution(gen_h5)
print(extracted_h5)
# Out:
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans

# %% [markdown]
# # EXEC TEST

# %%
! pip install -U pistonpy
# Out:
# Collecting pistonpy
#   Downloading pistonpy-0.0.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pistonpy) (2.32.3)
# Collecting typing (from pistonpy)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pistonpy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pistonpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pistonpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pistonpy) (2025.7.14)
# Downloading pistonpy-0.0.3-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: typing
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26304 sha256=a06a259c83592afd2b1612f855e043dc6074b8dd1ba1e705285b026aac56cbeb
#   Stored in directory: /root/.cache/pip/wheels/9d/67/2f/53e3ef32ec48d11d7d60245255e2d71e908201d20c880c08ee
# Successfully built typing
# Installing collected packages: typing, pistonpy
# Successfully installed pistonpy-0.0.3 typing-3.7.4.3

# %%
from pistonpy import PistonApp
piston = PistonApp()

# %%
def test_pipe(
    q,   # ? in fact only needs fields 'prompt' (import statements), 'test', 'entry_point'
    sol: str,            # the extract code
    py_version: str = "3.10.0",
) -> str:
    """
    Build a single Python script (solution + tests + driver), execute it
    via Piston, and return the stderr text (empty string means the test passed).

    py_version : str
        Python version tag recognised by Piston (default "3.10.0").

    return empty str if all pass
    """

    merged_code = (
        q["prompt"].rstrip()
        + "\n\n"
        + sol.rstrip()                    # candidate implementation
        + "\n\n"
        + q["test"].rstrip()            # assert-based tests
        + "\n\n"
        + f"check({q['entry_point']})\n"  # driver that triggers the tests
    )

    result = piston.run(
        language="python",
        version=py_version,
        code=merged_code,
    )
    #print("[test_pipeline] test complete")
    #print(result)

    return merged_code, result["run"]["stderr"]

# %% [markdown]
# #### code_ex from previous setion
# here use copy of the previous code gen print output (e.g. `extracted_e2`, `extracted_m4`, `extracted_h3`), since rerun code gen takes long time

# %%
# extracted_e2 = """
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
#         return sum(x == x[::-1] for x in words)
# """

# %% [markdown]
# #### h5 refine code test run

# %%
print(extracted_h5)
# Out:
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans

# %%
h5_refine_code="""
class Solution:
    def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
        items.sort(key=lambda x: -x[0])
        n = len(items)
        dp = [0] * (n + 1)
        for i in range(1, n + 1):
            dp[i] = dp[i - 1] + items[i - 1][0]
        ans = 0
        for i in range(k, n + 1):
            ans = max(ans, dp[i] + i - k)
        return ans
"""

# %%
_, result = test_pipe(hard_ds[4], h5_refine_code)
print(result)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/700e56ae-d2f3-4f64-8d49-7aeb2d5b0640/file0.code", line 33, in <module>
#     check(Solution().findMaximumElegance)
#   File "/piston/jobs/700e56ae-d2f3-4f64-8d49-7aeb2d5b0640/file0.code", line 29, in check
#     assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError

# %% [markdown]
# #### e2

# %%
test_code_e2, test_result_e2 = test_pipe(easy_ds[1],extracted_e2)
print(test_code_e2)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length
#
# def check(candidate):
#     assert candidate(words = ["cd","ac","dc","ca","zz"]) == 2
#     assert candidate(words = ["ab","ba","cc"]) == 1
#     assert candidate(words = ["aa","ab"]) == 0
#
# check(Solution().maximumNumberOfStringPairs)

# %%
print(test_result_e2)
# Out:
#   File "/piston/jobs/16d783f0-317b-4d25-8498-c7a52d11bf34/file0.code", line 27
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %% [markdown]
# #### e3

# %%
print(easy_ds[2]['test'])
print(easy_ds[2]['prompt'])
print(easy_ds[2]['entry_point'])
# Out:
# def check(candidate):
#     assert candidate(mainTank = 5, additionalTank = 10) == 60
#     assert candidate(mainTank = 1, additionalTank = 2) == 10
#
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# Solution().distanceTraveled

# %%
test_code_e3, test_result_e3 = test_pipe(easy_ds[2],extracted_e3)
print(test_code_e3)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# def check(candidate):
#     assert candidate(mainTank = 5, additionalTank = 10) == 60
#     assert candidate(mainTank = 1, additionalTank = 2) == 10
#
# check(Solution().distanceTraveled)

# %%
print(test_result_e3)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/00b69bc1-b1de-4039-b6cb-452b1ecbd214/file0.code", line 37, in <module>
#     check(Solution().distanceTraveled)
# AttributeError: 'Solution' object has no attribute 'distanceTraveled'

# %% [markdown]
# #### e4

# %%
test_code_e4, test_result_e4 = test_pipe(easy_ds[3],extracted_e4)
print(test_code_e4)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         n = len(nums)
#         dp = [0] * n
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 dp[i] = 1
#                 for j in range(i):
#                     if nums[j] % 2!= nums[i] % 2 and nums[j] <= threshold:
#                         dp[i] = max(dp[i], dp[j] + 1)
#         return max(dp)
#
# def check(candidate):
#     assert candidate(nums = [3,2,5,4], threshold = 5) == 3
#     assert candidate(nums = [1,2], threshold = 2) == 1
#     assert candidate(nums = [2,3,4,5], threshold = 4) == 3
#
# check(Solution().longestAlternatingSubarray)

# %%
print(test_result_e4)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/b447fb6f-ccfe-40d0-99e0-2fca33d8acdd/file0.code", line 32, in <module>
#     check(Solution().longestAlternatingSubarray)
#   File "/piston/jobs/b447fb6f-ccfe-40d0-99e0-2fca33d8acdd/file0.code", line 28, in check
#     assert candidate(nums = [3,2,5,4], threshold = 5) == 3
# AssertionError

# %% [markdown]
# #### e5

# %%
test_code_e5, test_result_e5 = test_pipe(easy_ds[4],extracted_e5)
print(test_code_e5)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# def check(candidate):
#     assert candidate(nums = [2,3,4,3,4]) == 4
#     assert candidate(nums = [4,5,6]) == 2
#
# check(Solution().alternatingSubarray)

# %%
print(test_result_e5)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/f75c347c-d5dc-4ede-94cb-80fa03ec67b7/file0.code", line 37, in <module>
#     check(Solution().alternatingSubarray)
# AttributeError: 'Solution' object has no attribute 'alternatingSubarray'

# %% [markdown]
# #### m2

# %%
test_code_m2, test_result_m2 = test_pipe(medium_ds[1],extracted_m2)
print(test_code_m2)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
#         cnt = Counter()
#         for s, t in logs:
#             cnt[s] += 1
#         ans = [0] * len(queries)
#         for i, q in enumerate(queries):
#             ans[i] = n - cnt[q] - (q - x > 0)
#         return ans
#
# def check(candidate):
#     assert candidate(n = 3, logs = [[1,3],[2,6],[1,5]], x = 5, queries = [10,11]) == [1,2]
#     assert candidate(n = 3, logs = [[2,4],[2,1],[1,2],[3,1]], x = 2, queries = [3,4]) == [0,1]
#
# check(Solution().countServers)

# %%
print(test_result_m2)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/290c0ad3-bdda-43a8-a12f-e1a38daa3bce/file0.code", line 29, in <module>
#     check(Solution().countServers)
#   File "/piston/jobs/290c0ad3-bdda-43a8-a12f-e1a38daa3bce/file0.code", line 26, in check
#     assert candidate(n = 3, logs = [[1,3],[2,6],[1,5]], x = 5, queries = [10,11]) == [1,2]
# AssertionError

# %% [markdown]
# #### m3

# %%
test_code_m3, test_result_m3 = test_pipe(medium_ds[2],extracted_m3)
print(test_code_m3)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# def check(candidate):
#     assert candidate(nums = [1,6,7,8], moveFrom = [1,7,2], moveTo = [2,9,5]) == [5,6,8,9]
#     assert candidate(nums = [1,1,3,3], moveFrom = [1,3], moveTo = [2,2]) == [2]
#
# check(Solution().relocateMarbles)

# %%
print(test_result_m3)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/ffd9f55c-bfbd-40b5-9182-646cd01555e8/file0.code", line 39, in <module>
#     check(Solution().relocateMarbles)
# AttributeError: 'Solution' object has no attribute 'relocateMarbles'

# %% [markdown]
# #### m4

# %%
test_code_m4, test_result_m4 = test_pipe(medium_ds[3],extracted_m4)
print(test_code_m4)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0-indexed integer array queries where queries[i] = [xi, yi].
# For the ith query, find the sum of the elements of nums that satisfy the following conditions:
#
# The row of nums that contains the element with the smallest value is the ith row.
# The column of nums that contains the element with the smallest value is the ith column.
# Return an array answer where answer[i] is the sum of the elements of nums that satisfy the conditions of the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumCells(self, nums: List[List[int]], queries: List[List[int]]) -> List[int]:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed 2D integer array nums.
# You are also given a 0
#
# def check(candidate):
#     assert candidate(n = 3, queries = [[0,0,1],[1,2,2],[0,2,3],[1,0,4]]) == 23
#     assert candidate(n = 3, queries = [[0,0,4],[0,1,2],[1,0,1],[0,2,3],[1,2,1]]) == 17
#
# check(Solution().matrixSumQueries)

# %%
print(test_result_m4)
# Out:
#   File "/piston/jobs/091e8d89-742b-4589-acae-4a00f2427b2d/file0.code", line 23
#     You are given a 0-indexed 2D integer array nums.
#                               ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# #### m5

# %%
test_code_m5, test_result_m5 = test_pipe(medium_ds[4],extracted_m5)
print(test_code_m5)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# def pairwise(iterable):
#     a, b = tee(iterable)
#     next(b, None)
#     return zip(a, b)
#
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return max(nums[i] - nums[~i] for i in range(len(nums) // 2))
#
# def check(candidate):
#     assert candidate(nums = [1,3,2,4]) == 1
#     assert candidate(nums = [100,1,10]) == 9
#
# check(Solution().findValueOfPartition)

# %%
print(test_result_m5)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/510177a9-7338-47bb-a668-cec3f51c4bab/file0.code", line 29, in <module>
#     check(Solution().findValueOfPartition)
#   File "/piston/jobs/510177a9-7338-47bb-a668-cec3f51c4bab/file0.code", line 26, in check
#     assert candidate(nums = [1,3,2,4]) == 1
# AssertionError

# %% [markdown]
# #### h2

# %%
test_code_h2, test_result_h2 = test_pipe(hard_ds[1],extracted_h2)
print(test_code_h2)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             for j in range(i + 1, n):
#                 ans += (nums[j] - nums[i]) > 1
#         return ans
#
# def check(candidate):
#     assert candidate(nums = [2,3,1,4]) == 3
#     assert candidate(nums = [1,3,3,3,5]) == 8
#
# check(Solution().sumImbalanceNumbers)

# %%
print(test_result_h2)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/c3f95d7a-2fae-4bd4-88a3-6779819930ff/file0.code", line 28, in <module>
#     check(Solution().sumImbalanceNumbers)
#   File "/piston/jobs/c3f95d7a-2fae-4bd4-88a3-6779819930ff/file0.code", line 25, in check
#     assert candidate(nums = [2,3,1,4]) == 3
# AssertionError

# %% [markdown]
# #### h3

# %%
test_code_h3, test_result_h3 = test_pipe(hard_ds[2],extracted_h3)
print(test_code_h3)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed string s of even length n.
# You can perform the following operation on s any number of times:
# Choose two indices i and j (0 <= i < j < n) such that i + 1 < j and s[i] = s[j] = '0'.
# Replace s[i] with '1' and s[j] with '1'.
# Return the minimum number of operations required to make s a semi-palindrome.
# A string is called a semi-palindrome if it can be split into two palindromes of equal length.
#
# Please complete the following python code precisely:
# ```python
# class
#
# def check(candidate):
#     assert candidate(s = "abcac", k = 2) == 1
#     assert candidate(s = "abcdef", k = 2) == 2
#     assert candidate(s = "aabbaa", k = 3) == 0
#
# check(Solution().minimumChanges)

# %%
print(test_result_h3)
# Out:
#   File "/piston/jobs/c3343490-1af8-43cd-8c53-af066bd5e9ad/file0.code", line 29
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %% [markdown]
# #### h4

# %%
test_code_h4, test_result_h4 = test_pipe(hard_ds[3],extracted_h4)
print(test_code_h4)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         ans = 0
#         for i in range(len(word)):
#             for j in range(i + 1, len(word) + 1):
#                 if word[i:j] not in forbidden:
#                     ans = max(ans, j - i)
#         return ans
#
# def check(candidate):
#     assert candidate(word = "cbaaaabc", forbidden = ["aaa","cb"]) == 4
#     assert candidate(word = "leetcode", forbidden = ["de","le","e"]) == 4
#
# check(Solution().longestValidSubstring)

# %%
print(test_result_h4)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/bc3e712c-b8aa-4883-b554-a6ad0512db59/file0.code", line 28, in <module>
#     check(Solution().longestValidSubstring)
#   File "/piston/jobs/bc3e712c-b8aa-4883-b554-a6ad0512db59/file0.code", line 25, in check
#     assert candidate(word = "cbaaaabc", forbidden = ["aaa","cb"]) == 4
# AssertionError

# %% [markdown]
# #### h5

# %%
test_code_h5, test_result_h5 = test_pipe(hard_ds[4],extracted_h5)
print(test_code_h5)
# Out:
# from typing import *
#
# from functools import *
# from collections import *
# from itertools import *
# from heapq import *
# from bisect import *
# from string import *
# from operator import *
# from math import *
# import math
# import datetime
# inf = float('inf')
#
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# def check(candidate):
#     assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
#     assert candidate(items = [[3,1],[3,1],[2,2],[5,3]], k = 3) == 19
#     assert candidate(items = [[1,1],[2,1],[3,1]], k = 3) == 7
#
# check(Solution().findMaximumElegance)

# %%
print(test_result_h5)
# Out:
# Traceback (most recent call last):
#   File "/piston/jobs/7bc5b6a6-627a-477d-abc0-6e32bb6fbd01/file0.code", line 32, in <module>
#     check(Solution().findMaximumElegance)
#   File "/piston/jobs/7bc5b6a6-627a-477d-abc0-6e32bb6fbd01/file0.code", line 28, in check
#     assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError

# %% [markdown]
# # REFINE

# %%
REFINE_TEMP = """
<issue_start>username_0: {instruction}\n\n‘‘‘{buggy_function}‘‘‘\nUpvotes: 100<issue_comment>
username_1: Sure, here is the fixed code.\n\n‘‘‘{function_start}
"""

# %%
def extract_assertion(s) -> str:
    """
    Return substring from the first occurrence of 'assert' (case-insensitive) to the end.
    If no 'assert' is found, return the original string.
    """
    m = re.search(r'\bassert\b', s, flags=re.IGNORECASE)
    return s[m.start():] if m else s


def get_header(s) -> str | None:
    """
    s is query
    Return the substring that begins with the first trio of back-ticks (```)
    and ends just before the second trio, keeping the opener but not the
    closer.

    If fewer than two sets of back-ticks exist, return None.
    """
    start = s.find("```")
    if start == -1:
        return None                    # no opening trio
    end = s.find("```", start + 3)
    if end == -1:
        return None                    # no closing trio
    return s[start:end]

# %% [markdown]
# ### e2

# %%
assert_e2 = extract_assertion(test_result_e2)
print(assert_e2)
# Out:
#   File "/piston/jobs/16d783f0-317b-4d25-8498-c7a52d11bf34/file0.code", line 27
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
header_e2 = get_header(easy_ds[1]['query'])
print(header_e2)
# Out:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:

# %%
refine_prompt_e2 = REFINE_TEMP.format( \
    instruction="Fix code: " + assert_e2 , \
    buggy_function=extracted_e2, \
    function_start=header_e2)
print(refine_prompt_e2)
# Out:
# <issue_start>username_0: Fix code:   File "/piston/jobs/16d783f0-317b-4d25-8498-c7a52d11bf34/file0.code", line 27
#
#     ^
# SyntaxError: invalid non-printable character U+00A0
#
#
# ‘‘‘class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length and subtract 1 from nums[i] at most k times.
# Return the maximum possible sum of nums after performing at most one operation.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int], k: int) -> int:
# ```
#
#
#
# <start>
#
# You are given a 0-indexed integer array nums.
# You are also given an integer k.
# In one operation, you can choose an index i where 0 <= i < nums.length‘‘‘
# Upvotes: 100<issue_comment>
# username_1: Sure, here is the fixed code.
#
# ‘‘‘```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:

# %%
raw_refine_e2 = generate_refine(refine_prompt_e2)
print(raw_refine_e2)

# %% [markdown]
# ### e3

# %%
assert_e3 = extract_assertion(test_result_e3)
print(assert_e3)

# %%
header_e3 = get_header(easy_ds[2]['query'])
print(header_e3)

# %%
refine_prompt_e3 = REFINE_TEMP.format( \
    instruction="Fix code: " + assert_e3 , \
    buggy_function=extracted_e3, \
    function_start=header_e3)
print(refine_prompt_e3)

# %%
raw_refine_e3 = generate_refine(refine_prompt_e3)
print(raw_refine_e3)

# %% [markdown]
# ### h5

# %% [markdown]
# #### make prompt

# %%
print(extracted_h5)
# Out:
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans

# %%
assert_h5 = extract_assertion(test_result_h5)
print(assert_h5)
# Out:
# assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError

# %%
header_h5 = get_header(hard_ds[4]['query'])
print(header_h5)
# Out:
# ```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:

# %%
refine_prompt_h5 = REFINE_TEMP.format( \
    instruction="Fix code: " + assert_h5 , \
    buggy_function=extracted_h5, \
    function_start=header_h5)
print(refine_prompt_h5)
# Out:
# <issue_start>username_0: Fix code: assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError
#
#
# ‘‘‘class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans‘‘‘
# Upvotes: 100<issue_comment>
# username_1: Sure, here is the fixed code.
#
# ‘‘‘```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:

# %%
refine_prompt_h5_v2 = REFINE_TEMP.format( \
    instruction="Fix code: " + test_result_h5 , \
    buggy_function=extracted_h5, \
    function_start=header_h5)
print(refine_prompt_h5)
# Out:
# <issue_start>username_0: Fix code: assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError
#
#
# ‘‘‘class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans‘‘‘
# Upvotes: 100<issue_comment>
# username_1: Sure, here is the fixed code.
#
# ‘‘‘```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:

# %% [markdown]
# #### refine gen

# %%
def generate_refine (
    prompt: str,
    max_new_tokens: int = 2048,
) -> str:

    def strip_after_end(text: str) -> str:
        return text.split("<end>", 1)[0].rstrip()

    # encode
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    prompt_len = inputs.input_ids.shape[-1]

    # generate
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.2, # param from paper eval expermients
            top_p=0.95,
            do_sample=True,
        )

    # discard input
    raw = tokenizer.decode(output_ids[0])
    # gen_text = tokenizer.decode(output_ids[0][prompt_len:] )

    #eturn raw, strip_after_end(gen_text)
    return raw

# %%
print(hard_ds[4]["query"])
# Out:
# You are given a 0-indexed 2D integer array items of length n and an integer k.
# items[i] = [profiti, categoryi], where profiti and categoryi denote the profit and category of the ith item respectively.
# Let's define the elegance of a subsequence of items as total_profit + distinct_categories2, where total_profit is the sum of all profits in the subsequence, and distinct_categories is the number of distinct categories from all the categories in the selected subsequence.
# Your task is to find the maximum elegance from all subsequences of size k in items.
# Return an integer denoting the maximum elegance of a subsequence of items with size exactly k.
# Note: A subsequence of an array is a new array generated from the original array by deleting some elements (possibly none) without changing the remaining elements' relative order.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
# ```

# %%
raw_refine_h5 = generate_refine(refine_prompt_h5)
print(raw_refine_h5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <issue_start>username_0: Fix code: assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError
#
#
# ‘‘‘class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans‘‘‘
# Upvotes: 100<issue_comment>
# username_1: Sure, here is the fixed code.
#
# ‘‘‘```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#
#  items.sort(key=lambda x: -x[0])
#  n = len(items)
#  dp = [0] \* (n + 1)
#  for i in range(1, n + 1):
#  dp[i] = dp[i - 1] + items[i - 1][0]
#  ans = 0
#  for i in range(k, n + 1):
#  ans = max(ans, dp[i] + i - k)
#  return ans
#
# ```
#
# ‘‘‘
# Upvotes: 0 <issue_comment>username_2: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_3: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_4: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_5: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_6: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_7: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_8: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_9: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_10: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_11: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_12: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_13: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 0 <issue_comment>username_14: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):

# %%
# complete err message
raw_refine_h5_v2 = generate_refine(refine_prompt_h5_v2)
print(raw_refine_h5_v2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <issue_start>username_0: Fix code: Traceback (most recent call last):
#   File "/piston/jobs/7bc5b6a6-627a-477d-abc0-6e32bb6fbd01/file0.code", line 32, in <module>
#     check(Solution().findMaximumElegance)
#   File "/piston/jobs/7bc5b6a6-627a-477d-abc0-6e32bb6fbd01/file0.code", line 28, in check
#     assert candidate(items = [[3,2],[5,1],[10,1]], k = 2) == 17
# AssertionError
#
#
# ‘‘‘class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans‘‘‘
# Upvotes: 100<issue_comment>
# username_1: Sure, here is the fixed code.
#
# ‘‘‘```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#
#  items.sort(key=lambda x: -x[0])
#  n = len(items)
#  dp = [0] \* (n + 1)
#  for i in range(1, n + 1):
#  dp[i] = dp[i - 1] + items[i - 1][0]
#  ans = 0
#  for i in range(k, n + 1):
#  ans = max(ans, dp[i] + i - k)
#  return ans
# ‘‘‘
# Upvotes: 1 <issue_comment>username_2: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_3: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_4: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_5: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_6: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_7: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_8: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_9: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_10: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_11: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_12: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_13: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i] = dp[i - 1] + items[i - 1][0]
#         ans = 0
#         for i in range(k, n + 1):
#             ans = max(ans, dp[i] + i - k)
#         return ans
#
# ```
# Upvotes: 1 <issue_comment>username_14: ```
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         n = len(items)
#         dp = [0] * (n + 1)
#         for i in range(1, n + 1):
#             dp[i]

# %% [markdown]
# # EXPLAIN GEN

# %%
for e in example_ds:
    print(e["task_id"])
# Out:
# sum-of-squares-of-special-elements
# find-the-longest-equal-subarray
# maximum-sum-queries

# %%
sol= """
class Solution:
    def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
        n = len(nums1)
        nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
        nums2.sort()
        ans = [-1] * len(queries)
        j = 0
        tree = BinaryIndexedTree(n)
        for i, (x, y) in enumerate(queries):
            while j < n and nums[j][0] >= x:
                k = n - bisect_left(nums2, nums[j][1])
                tree.update(k, nums[j][0] + nums[j][1])
                j += 1
            k = n - bisect_left(nums2, y)
            ans[i] = tree.query(k)
        return ans
"""
query =

# %%
EXPLAIN_TEMP = """
## Task
{query}
## Solution
{sol}
## Explanation
"""

# %%
inputs = tokenizer(EXPLAIN_TEMP.format(sol=sol), return_tensors="pt").to(device)
with torch.no_grad():
    out  = model.generate(
        **inputs,
        max_new_tokens=512,
        temperature=0.2, # param from paper eval expermients
        top_p=0.95,
        do_sample=True,)

# %%
raw = tokenizer.decode(out[0])
print(raw)
# Out:
# ## Solution
#
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
#         n = len(nums1)
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         ans = [-1] * len(queries)
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i, (x, y) in enumerate(queries):
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# We can use a binary indexed tree to find the maximum sum of the first $k$ elements of the sorted array.
#
# ## Complexity
#
# - Time complexity: $O(n \log n + m \log n)$, where $n$ is the length of `nums1`, $m$ is the length of `queries`.
# - Space complexity: $O(n)$, the space used by the binary indexed tree.
# <file_sep>/problems/0350.intersection-of-two-arrays-ii/solution.py
# class Solution:
#     def intersect(self, nums1: List[int], nums2: List[int]) -> List[int]:
#         d = {}
#         for num in nums1:
#             d[num] = d.get(num, 0) + 1
#         ans = []
#         for num in nums2:
#             if num in d and d[num] > 0:
#                 ans.append(num)
#                 d[num] -= 1
#         return ans
# <file_sep>/problems/0560.subarray-sum-equals-k/solution.py
# class Solution:
#     def subarraySum(self, nums: List[int], k: int) -> int:
#         d = {0: 1}
#         ans = 0
#         s = 0
#         for num in nums:
#             s += num
#             ans += d.get(s - k, 0)
#             d[s] = d.get(s, 0) + 1
#         return ans
# <file_sep>/problems/0416.partition-equal-subset-sum/solution.py
# class Solution:
#     def canPartition(self, nums: List[int]) -> bool:
#         n = len(nums)
#         s = sum(nums)
#         if s % 2 == 1:
#             return False
#         s //= 2
#         dp = [False] * (s + 1)
#         dp[0] = True
#         for num in nums:
#             for i in range(s, num - 1, -1):
#                 dp[i] |= dp[i - num]
#         return dp[s]
# <file_sep>/problems/0322.coin-change/solution.py
# class Solution:
#     def coinChange(self, coins: List[int], amount: int) -> int:
#         dp = [amount + 1] *

# %% [markdown]
# ## few shot explain

# %%
FEW_SHOT_EXPLAIN_TEMP = """
<start>
## Task
{query}
## Solution
{completion}
## Explanation
{explain}
<end>
"""

TARGET_EXPLAIN_TEMP = """
<start>
<fim_prefix>
## Task
{query}
## Solution
{completion}
<fim_suffix>
## Explanation
<fim_middle>"""
# Prefix = the task + solution code
# Suffix = the literal line “## Explanation” (so the heading is shown to the model)
# Middle  = the explanation the model will now generate

# %% [markdown]
# ### few shot part

# %%
for e in example_ds:
    print("TASK:", e["task_id"])
    print(e["query"])
    print(e["completion"])
    print("================")
# Out:
# TASK: sum-of-squares-of-special-elements
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ================
# TASK: find-the-longest-equal-subarray
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ================
# TASK: maximum-sum-queries
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ================

# %%
EXPLAINS = [
    # 1 ── sum-of-squares-of-special-elements
    """
Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
divides n, that element is “special”; square it and accumulate. The one-liner
uses a comprehension, giving O(n) time and O(1) extra space.
""",

    # 2 ── find-the-longest-equal-subarray
    """
Slide a window [l, r] while counting element frequencies. Keep mx, the highest
frequency inside the window. If window_size − mx > k (too many deletions
needed), move l right and update counts until the window is feasible. The
largest mx seen is the answer. Time O(n); space O(u) where u is the number of
distinct values in the window.
""",

    # 3 ── maximum-sum-queries
    """
Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
order; sort queries in descending xi order. Sweep: for each xi, insert all
points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
O((n + q) log n) time and O(n) space.
"""
]
example_blocks_lst = []

# %%
for i, exp in enumerate(EXPLAINS):
  example_blocks_lst.append(FEW_SHOT_EXPLAIN_TEMP.format(query=example_ds[i]["query"], completion=example_ds[i]["completion"], explain=exp))

# %%
few_shot_par_explain = "\n\n".join(example_blocks_lst)
print(few_shot_par_explain)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>

# %% [markdown]
# ### make prompt explain

# %%
def make_prompt_explain(q, target_q_code):
  target_part = TARGET_EXPLAIN_TEMP.format(query=q["query"],completion=target_q_code)
  return few_shot_par_explain + "\n\n" + target_part

# %% [markdown]
# ### test on 4 easy + 4M + 4H
# - (here use target_q['completion'], while in real pipeline, should use code generated and refined from previous stage)

# %%
def generate_explain (
    prompt: str,
    max_new_tokens: int = 2048,
) -> str:

    def strip_after_end(text: str) -> str:
        return text.split("<end>", 1)[0].rstrip()

    # encode
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    prompt_len = inputs.input_ids.shape[-1]

    # generate
    with torch.no_grad():
        output_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.2, # param from paper eval expermients
            top_p=0.95,
            do_sample=True,
        )

    # discard input
    raw = tokenizer.decode(output_ids[0])
    gen_text = tokenizer.decode(output_ids[0][prompt_len:] )
    # discard after <end>
    return raw, strip_after_end(gen_text)

# %% [markdown]
# #### easy2

# %%
prompt_exp_e2 = make_prompt_explain(easy_ds[1], easy_ds[1]["completion"])
print(prompt_exp_e2)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
#         cnt = Counter()
#         ans = 0
#         for w in words:
#             ans += cnt[w[::-1]]
#             cnt[w] += 1
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw, exp_e2 = generate_explain(prompt_exp_e2)
print(raw)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed array words consisting of distinct strings.
# The string words[i] can be paired with the string words[j] if:
#
# The string words[i] is equal to the reversed string of words[j].
# 0 <= i < j < words.length.
#
# Return the maximum number of pairs that can be formed from the array words.
# Note that each string can belong in at most one pair.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumNumberOfStringPairs(self, words: List[str]) -> int:
#         cnt = Counter()
#         ans = 0
#         for w in words:
#             ans += cnt[w[::-1]]
#             cnt[w] += 1
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Maintain a counter cnt for each word. For each word, check if its reverse is
# already in the counter. If so, the pair is formed; increment ans. Finally,
# increment cnt[w] for each word. Overall complexity: O(n) time and O(n)
# space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
#
# The number of occurrences of the letter 'a' is equal to the number of occurrences of the letter 'b'.
# The number of occurrences of the letter 'b' is equal to the number of occurrences of the letter 'c'.
# The number of occurrences of the letter 'c' is equal to the number of occurrences of the letter 'a'.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. For each letter, check if the
# number of occurrences is equal to the number of occurrences of its opposite
# letter. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s and an integer k.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains k or more consecutive vowels.
# The string s contains k or more consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self, s: str, k: int) -> bool:
# ```
# ## Solution
# class Solution:
#     def isGoodString(self, s: str, k: int) -> bool:
#         return s.count("a") >= k and s.count("e") >= k and s.count("i") >= k and s.count("o") >= k and s.count("u") >= k
#
# ## Explanation
#
# Check if the string contains k or more consecutive vowels, k or more
# consonants, and so on. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains no two consecutive vowels.
# The string s contains no two consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isGoodString(self, s: str) -> bool:
#         return s.count("a") % 2 == 0 and s.count("e") % 2 == 0 and s.count("i") % 2 == 0 and s.count("o") % 2 == 0 and s.count("u") % 2 == 0
#
# ## Explanation
#
# Check if the string contains no two consecutive vowels, no two consecutive
# consonants, and so on. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains no two consecutive vowels.
# The string s contains no two consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isGoodString(self, s: str) -> bool:
#         return s.count("a") % 2 == 0 and s.count("e") % 2 == 0 and s.count("i") % 2 == 0 and s.count("o") % 2 == 0 and s.count("u") % 2 == 0
#
# ## Explanation
#
# Check if the string contains no two consecutive vowels, no two consecutive
# consonants, and so on. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains no two consecutive vowels.
# The string s contains no two consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isGoodString(self, s: str) -> bool:
#         return s.count("a") % 2 == 0 and s.count("e") % 2 == 0 and s.count("i") % 2 == 0 and s.count("o") % 2 == 0 and s.count("u") % 2 == 0
#
# ## Explanation
#
# Check if the string contains no two consecutive vowels, no two consecutive
# consonants, and so on. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains no two consecutive vowels.
# The string s contains no two consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isGoodString(self, s: str) -> bool:
#         return s.count("a") % 2 == 0 and s.count("e") % 2 == 0 and s.count("i") % 2 == 0 and s.count("o") % 2 == 0 and s.count("u") % 2 == 0
#
# ## Explanation
#
# Check if the string contains no two consecutive vowels, no two consecutive
# consonants, and so on. Overall complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called good if the following conditions are satisfied:
#
# The string s contains no two consecutive vowels.
# The string s contains no two consecutive consonants.
# Return true if s is good, and false otherwise.
# A string s is vowel if it contains any of the characters 'a', 'e', 'i', 'o', or 'u'.
# A string s is consonant if it does not contain any of the characters 'a', 'e', 'i', 'o', or 'u'.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isGoodString(self,

# %%
print(exp_e2)
# Out:
# ## Explanation
#
# Maintain a counter cnt for each word. For each word, check if its reverse is
# already in the counter. If so, the pair is formed; increment ans. Finally,
# increment cnt[w] for each word. Overall complexity: O(n) time and O(n)
# space.

# %% [markdown]
# #### easy3

# %%
prompt_exp_e3 = make_prompt_explain(easy_ds[2], easy_ds[2]["completion"])
print(prompt_exp_e3)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# A truck has two fuel tanks. You are given two integers, mainTank representing the fuel present in the main tank in liters and additionalTank representing the fuel present in the additional tank in liters.
# The truck has a mileage of 10 km per liter. Whenever 5 liters of fuel get used up in the main tank, if the additional tank has at least 1 liters of fuel, 1 liters of fuel will be transferred from the additional tank to the main tank.
# Return the maximum distance which can be traveled.
# Note: Injection from the additional tank is not continuous. It happens suddenly and immediately for every 5 liters consumed.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
# ```
# ## Solution
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
#         ans = cur = 0
#         while mainTank:
#             cur += 1
#             ans += 10
#             mainTank -= 1
#             if cur % 5 == 0 and additionalTank:
#                 additionalTank -= 1
#                 mainTank += 1
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_e3, exp_e3 = generate_explain(prompt_exp_e3)
print(raw_e3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# A truck has two fuel tanks. You are given two integers, mainTank representing the fuel present in the main tank in liters and additionalTank representing the fuel present in the additional tank in liters.
# The truck has a mileage of 10 km per liter. Whenever 5 liters of fuel get used up in the main tank, if the additional tank has at least 1 liters of fuel, 1 liters of fuel will be transferred from the additional tank to the main tank.
# Return the maximum distance which can be traveled.
# Note: Injection from the additional tank is not continuous. It happens suddenly and immediately for every 5 liters consumed.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
# ```
# ## Solution
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
#         ans = cur = 0
#         while mainTank:
#             cur += 1
#             ans += 10
#             mainTank -= 1
#             if cur % 5 == 0 and additionalTank:
#                 additionalTank -= 1
#                 mainTank += 1
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Inject fuel from the additional tank to the main tank until the main tank is
# empty.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s. You have to perform the following operation on the string any number of times:
# Choose an index i such that 0 <= i < s.length and s[i] == '0'.
# Replace s[i] with '1'.
# Return the minimum number of operations required to make s a palindrome.
# Note: A palindrome is a string that reads the same forward and backward.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minOperations(self, s: str) -> int:
# ```
# ## Solution
# class Solution:
#     def minOperations(self, s: str) -> int:
#         ans = 0
#         for i in range(len(s)):
#             if s[i] == "0":
#                 ans += 1
#                 s = s[:i] + "1" + s[i + 1 :]
#         return ans
#
# ## Explanation
#
# Scan the string from left to right. If we find a 0, we increment the answer and
# replace it with a 1.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
# Choose two indices i and j such that 0 <= i < j < nums.length and nums[i] > 0.
# Decrease nums[i] by 1 and increase nums[j] by 1.
# Return the maximum possible sum of nums after performing the operations.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             for j in range(i + 1, len(nums)):
#                 ans = max(ans, nums[i] + nums[j])
#                 nums[i] -= 1
#                 nums[j] += 1
#         return ans
#
# ## Explanation
#
# For each index i, scan the array from right to left and for each index j > i,
# update the answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum length of a substring in s such that the sum of the ASCII values of each character in the substring is less than or equal to lefti and the sum of the ASCII values of each character in the substring is greater than or equal to righti.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSubstrings(self, s: str) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def sumOfSubstrings(self, s: str) -> List[int]:
#         ans = [0] * len(s)
#         for i in range(len(s)):
#             ans[i] = sum(map(ord, s[i:]))
#             if i:
#                 ans[i] += ans[i - 1]
#         return ans
#
# ## Explanation
#
# Compute the sum of the ASCII values of each substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
# Choose an index i such that 0 <= i < nums.length and nums[i] > 0.
# Decrease nums[i] by 1.
# Return the maximum possible sum of nums after performing the operations.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             for j in range(i + 1, len(nums)):
#                 ans = max(ans, nums[i] + nums[j])
#                 nums[i] -= 1
#                 nums[j] += 1
#         return ans
#
# ## Explanation
#
# For each index i, scan the array from right to left and for each index j > i,
# update the answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
# Choose an index i such that 0 <= i < nums.length and nums[i] > 0.
# Decrease nums[i] by 1.
# Return the maximum possible sum of nums after performing the operations.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             for j in range(i + 1, len(nums)):
#                 ans = max(ans, nums[i] + nums[j])
#                 nums[i] -= 1
#                 nums[j] += 1
#         return ans
#
# ## Explanation
#
# For each index i, scan the array from right to left and for each index j > i,
# update the answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum length of a substring in s such that the sum of the ASCII values of each character in the substring is less than or equal to lefti and the sum of the ASCII values of each character in the substring is greater than or equal to righti.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSubstrings(self, s: str) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def sumOfSubstrings(self, s: str) -> List[int]:
#         ans = [0] * len(s)
#         for i in range(len(s)):
#             ans[i] = sum(map(ord, s[i:]))
#             if i:
#                 ans[i] += ans[i - 1]
#         return ans
#
# ## Explanation
#
# Compute the sum of the ASCII values of each substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
# Choose an index i such that 0 <= i < nums.length and nums[i] > 0.
# Decrease nums[i] by 1.
# Return the maximum possible sum of nums after performing the operations.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             for j in range(i + 1, len(nums)):
#                 ans = max(ans, nums[i] + nums[j])
#                 nums[i] -= 1
#                 nums[j] += 1
#         return ans
#
# ## Explanation
#
# For each index i, scan the array from right to left and for each index j > i,
# update the answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
# Choose an index i such that 0 <= i < nums.length and nums[i] > 0.
# Decrease nums[i] by 1.
# Return the maximum possible sum of nums after performing the operations.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             for j in range(i + 1, len(nums)):
#                 ans = max(ans, nums[i] + nums[j])
#                 nums[i] -= 1
#                 nums[j] += 1
#         return ans
#
# ## Explanation
#
# For each index i, scan the array from right to left and for each index j > i,

# %%
print(easy_ds[2]["completion"])
# Out:
# class Solution:
#     def distanceTraveled(self, mainTank: int, additionalTank: int) -> int:
#         ans = cur = 0
#         while mainTank:
#             cur += 1
#             ans += 10
#             mainTank -= 1
#             if cur % 5 == 0 and additionalTank:
#                 additionalTank -= 1
#                 mainTank += 1
#         return ans

# %%
print(exp_e3)
# Out:
# ## Explanation
#
# Inject fuel from the additional tank to the main tank until the main tank is
# empty.

# %% [markdown]
# #### easy4

# %%
prompt_exp_e4 = make_prompt_explain(easy_ds[3], easy_ds[3]["completion"])
print(prompt_exp_e4)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums and an integer threshold.
# Find the length of the longest subarray of nums starting at index l and ending at index r (0 <= l <= r < nums.length) that satisfies the following conditions:
#
# nums[l] % 2 == 0
# For all indices i in the range [l, r - 1], nums[i] % 2 != nums[i + 1] % 2
# For all indices i in the range [l, r], nums[i] <= threshold
#
# Return an integer denoting the length of the longest such subarray.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         ans, n = 0, len(nums)
#         for l in range(n):
#             if nums[l] % 2 == 0 and nums[l] <= threshold:
#                 r = l + 1
#                 while r < n and nums[r] % 2 != nums[r - 1] % 2 and nums[r] <= threshold:
#                     r += 1
#                 ans = max(ans, r - l)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_e4, exp_e4 = generate_explain(prompt_exp_e4)
print(raw_e4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums and an integer threshold.
# Find the length of the longest subarray of nums starting at index l and ending at index r (0 <= l <= r < nums.length) that satisfies the following conditions:
#
# nums[l] % 2 == 0
# For all indices i in the range [l, r - 1], nums[i] % 2!= nums[i + 1] % 2
# For all indices i in the range [l, r], nums[i] <= threshold
#
# Return an integer denoting the length of the longest such subarray.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         ans, n = 0, len(nums)
#         for l in range(n):
#             if nums[l] % 2 == 0 and nums[l] <= threshold:
#                 r = l + 1
#                 while r < n and nums[r] % 2!= nums[r - 1] % 2 and nums[r] <= threshold:
#                     r += 1
#                 ans = max(ans, r - l)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Sweep from left to right. For each l, find the first r such that nums[r] % 2
# != nums[r - 1] % 2 and nums[r] <= threshold. The answer is the maximum of
# r - l.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called alternating if for all indices i (0 <= i < nums.length), either:
#
# nums[i] % 2 == 0 and nums[i + 1] % 2!= 0, or
# nums[i] % 2!= 0 and nums[i + 1] % 2 == 0.
# Return the length of the longest alternating subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int]) -> int:
#         ans, n = 0, len(nums)
#         for l in range(n):
#             if nums[l] % 2 == 0 and nums[l] % 2!= nums[l + 1] % 2:
#                 r = l + 1
#                 while r < n and nums[r] % 2!= nums[r - 1] % 2:
#                     r += 1
#                 ans = max(ans, r - l)
#         return ans
#
# ## Explanation
#
# Sweep from left to right. For each l, find the first r such that nums[r] % 2
# != nums[r - 1] % 2. The answer is the maximum of r - l.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called alternating if for all indices i (0 <= i < nums.length), either:
#
# nums[i] % 2 == 0 and nums[i + 1] % 2!= 0, or
# nums[i] % 2!= 0 and nums[i + 1] % 2 == 0.
# Return the length of the longest alternating subarray of nums.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int]) -> int:
#         ans, n = 0, len(nums)
#         for l in range(n):
#             if nums[l] % 2 == 0 and nums[l] % 2!= nums[l + 1] % 2:
#                 r = l + 1
#                 while r < n and nums[r] % 2!= nums[r - 1] % 2:
#                     r += 1
#                 ans = max(ans, r - l)
#         return ans
# <file_sep><fim_prefix><fim_suffix>  return ans
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is a contiguous non-empty sequence of elements within nums.
# The sum of a subarray is the sum of all the elements in the subarray.
# Return the number of distinct sums of all non-empty subarrays of nums. Since the answer may be very large, return it modulo 109 + 7.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             s = 0
#             for j in range(i, len(nums)):
#                 s += nums[j]
#                 ans += s
#         return ans % (10 ** 9 + 7)
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is a contiguous non-empty sequence of elements within nums.
# The sum of a subarray is the sum of all the elements in the subarray.
# Return the number of distinct sums of all non-empty subarrays of nums. Since the answer may be very large, return it modulo 109 + 7.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             s = 0
#             for j in range(i, len(nums)):
#                 s += nums[j]
#                 ans += s
#         return ans % (10 ** 9 + 7)
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is a contiguous non-empty sequence of elements within nums.
# The sum of a subarray is the sum of all the elements in the subarray.
# Return the number of distinct sums of all non-empty subarrays of nums. Since the answer may be very large, return it modulo 109 + 7.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             s = 0
#             for j in range(i, len(nums)):
#                 s += nums[j]
#                 ans += s
#         return ans % (10 ** 9 + 7)
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is a contiguous non-empty sequence of elements within nums.
# The sum of a subarray is the sum of all the elements in the subarray.
# Return the number of distinct sums of all non-empty subarrays of nums. Since the answer may be very large, return it modulo 109 + 7.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             s = 0
#             for j in range(i, len(nums)):
#                 s += nums[j]
#                 ans += s
#         return ans % (10 ** 9 + 7)
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is a contiguous non-empty sequence of elements within nums.
# The sum of a subarray is the sum of all the elements in the subarray.
# Return the number of distinct sums of all non-empty subarrays of nums. Since the answer may be very large, return it modulo 109 + 7.
# Note: A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def distinctSums(self, nums: List[int]) -> int:
#         ans = 0
#         for i in range(len(nums)):
#             s = 0
#             for j in range(i, len(nums)):
#                 s += nums[j]
#                 ans += s
#         return ans % (10 ** 9 + 7)
#
# ## Explanation
#
# The answer is the number of subarrays with sum 0.
#
# <end>
#
#
#
# <start>
# ##

# %%
print(easy_ds[3]["completion"])
# Out:
# class Solution:
#     def longestAlternatingSubarray(self, nums: List[int], threshold: int) -> int:
#         ans, n = 0, len(nums)
#         for l in range(n):
#             if nums[l] % 2 == 0 and nums[l] <= threshold:
#                 r = l + 1
#                 while r < n and nums[r] % 2 != nums[r - 1] % 2 and nums[r] <= threshold:
#                     r += 1
#                 ans = max(ans, r - l)
#         return ans

# %%
print(exp_e4)
# Out:
# ## Explanation
#
# Sweep from left to right. For each l, find the first r such that nums[r] % 2
# != nums[r - 1] % 2 and nums[r] <= threshold. The answer is the maximum of
# r - l.

# %% [markdown]
# #### easy5

# %%
prompt_exp_e5 = make_prompt_explain(easy_ds[4], easy_ds[4]["completion"])
print(prompt_exp_e5)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
#         ans, n = -1, len(nums)
#         for i in range(n):
#             k = 1
#             j = i
#             while j + 1 < n and nums[j + 1] - nums[j] == k:
#                 j += 1
#                 k *= -1
#             if j - i + 1 > 1:
#                 ans = max(ans, j - i + 1)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_e5, exp_e5 = generate_explain(prompt_exp_e5)
print(raw_e5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums. A subarray s of length m is called alternating if:
#
# m is greater than 1.
# s1 = s0 + 1.
# The 0-indexed subarray s looks like [s0, s1, s0, s1,...,s(m-1) % 2]. In other words, s1 - s0 = 1, s2 - s1 = -1, s3 - s2 = 1, s4 - s3 = -1, and so on up to s[m - 1] - s[m - 2] = (-1)m.
#
# Return the maximum length of all alternating subarrays present in nums or -1 if no such subarray exists.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def alternatingSubarray(self, nums: List[int]) -> int:
#         ans, n = -1, len(nums)
#         for i in range(n):
#             k = 1
#             j = i
#             while j + 1 < n and nums[j + 1] - nums[j] == k:
#                 j += 1
#                 k *= -1
#             if j - i + 1 > 1:
#                 ans = max(ans, j - i + 1)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# For each starting index i, check if there is an alternating subarray starting
# at i. If so, keep track of the maximum length.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is called good if the sum of its elements is divisible by 3.
# Return the maximum length of a good subarray of nums. If no such subarray exists, return 0.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             s = 0
#             for j in range(i, n):
#                 s += nums[j]
#                 if s % 3 == 0:
#                     ans = max(ans, j - i + 1)
#         return ans
#
# ## Explanation
#
# For each starting index i, check if there is a good subarray starting at i. If
# so, keep track of the maximum length.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is called good if the sum of its elements is divisible by 3.
# Return the maximum length of a good subarray of nums. If no such subarray exists, return 0.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             s = 0
#             for j in range(i, n):
#                 s += nums[j]
#                 if s % 3 == 0:
#                     ans = max(ans, j - i + 1)
#         return ans
#
# ## Explanation
#
# For each starting index i, check if there is a good subarray starting at i. If
# so, keep track of the maximum length.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# A subarray of nums is called good if the sum of its elements is divisible by 3.
# Return the maximum length of a good subarray of nums. If no such subarray exists, return 0.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumGood(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             s = 0
#             for j in range(i, n):
#                 s += nums[j]
#                 if s % 3 == 0:
#                     ans = max(ans, j - i + 1)
#         return ans
# <file_sep><fim_prefix><fim_suffix> 1] = 1
#         for i in range(1, n):
#             for j in range(1, m):
#                 if s1[i - 1] == s2[j - 1]:
#                     dp[i][j] = dp[i - 1][j - 1]
#                 else:
#                     dp[i][j] = min(dp[i - 1][j], dp[i][j - 1]) + 1
#         return dp[n - 1][m - 1]
#
# ## Explanation
#
# Compute the LCS of s1 and s2. The answer is the length of the LCS plus the
# number of insertions and deletions needed to make s1 and s2 equal.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string t is a subsequence of s if it is obtained by deleting some (possibly zero) characters from s without changing the order of the remaining characters.
# For example, "abc" is a subsequence of "aebdc" (as you can delete the characters in positions 0, 3 and 4), and "aebdc" is not a subsequence of "aebdc" because you can only delete characters at positions 0, 3 and 4.
# Return the number of subsequences of s that are not subsequences of any other string in the array words.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
#         n = len(s)
#         m = len(words)
#         dp = [[0] * (n + 1) for _ in range(m + 1)]
#         for i in range(1, m + 1):
#             for j in range(1, n + 1):
#                 if words[i - 1][j - 1] == s[j - 1]:
#                     dp[i][j] = dp[i - 1][j - 1] + 1
#                 else:
#                     dp[i][j] = dp[i][j - 1]
#         ans = 0
#         for i in range(1, m + 1):
#             ans += n - dp[i][n]
#         return ans
#
# ## Explanation
#
# Compute the LCS of each word in words with s. The answer is the number of
# words that have the same LCS as s.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string t is a subsequence of s if it is obtained by deleting some (possibly zero) characters from s without changing the order of the remaining characters.
# For example, "abc" is a subsequence of "aebdc" (as you can delete the characters in positions 0, 3 and 4), and "aebdc" is not a subsequence of "aebdc" because you can only delete characters at positions 0, 3 and 4.
# Return the number of subsequences of s that are not subsequences of any other string in the array words.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
#         n = len(s)
#         m = len(words)
#         dp = [[0] * (n + 1) for _ in range(m + 1)]
#         for i in range(1, m + 1):
#             for j in range(1, n + 1):
#                 if words[i - 1][j - 1] == s[j - 1]:
#                     dp[i][j] = dp[i - 1][j - 1] + 1
#                 else:
#                     dp[i][j] = dp[i][j - 1]
#         ans = 0
#         for i in range(1, m + 1):
#             ans += n - dp[i][n]
#         return ans
#
# ## Explanation
#
# Compute the LCS of each word in words with s. The answer is the number of
# words that have the same LCS as s.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string t is a subsequence of s if it is obtained by deleting some (possibly zero) characters from s without changing the order of the remaining characters.
# For example, "abc" is a subsequence of "aebdc" (as you can delete the characters in positions 0, 3 and 4), and "aebdc" is not a subsequence of "aebdc" because you can only delete characters at positions 0, 3 and 4.
# Return the number of subsequences of s that are not subsequences of any other string in the array words.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def countGood(self, s: str, words: List[str]) -> int:
#         n = len(s)
#         m = len(words)
#         dp = [[0] * (n + 1) for _ in range(m + 1)]
#         for i in range(1, m + 1):
#             for j in range(1, n + 1):
#                 if words[i - 1][j - 1] == s[j - 1]:

# %%
print(exp_e5)
# Out:
# ## Explanation
#
# For each starting index i, check if there is an alternating subarray starting
# at i. If so, keep track of the maximum length.

# %% [markdown]
# #### medium2

# %%
prompt_exp_m2 = make_prompt_explain(medium_ds[1], medium_ds[1]["completion"])
print(prompt_exp_m2)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given an integer n denoting the total number of servers and a 2D 0-indexed integer array logs, where logs[i] = [server_id, time] denotes that the server with id server_id received a request at time time.
# You are also given an integer x and a 0-indexed integer array queries.
# Return a 0-indexed integer array arr of length queries.length where arr[i] represents the number of servers that did not receive any requests during the time interval [queries[i] - x, queries[i]].
# Note that the time intervals are inclusive.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def countServers(
#         self, n: int, logs: List[List[int]], x: int, queries: List[int]
#     ) -> List[int]:
#         cnt = Counter()
#         logs.sort(key=lambda x: x[1])
#         ans = [0] * len(queries)
#         j = k = 0
#         for r, i in sorted(zip(queries, count())):
#             l = r - x
#             while k < len(logs) and logs[k][1] <= r:
#                 cnt[logs[k][0]] += 1
#                 k += 1
#             while j < len(logs) and logs[j][1] < l:
#                 cnt[logs[j][0]] -= 1
#                 if cnt[logs[j][0]] == 0:
#                     cnt.pop(logs[j][0])
#                 j += 1
#             ans[i] = n - len(cnt)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_m2, exp_m2 = generate_explain(prompt_exp_m2)
print(raw_m2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given an integer n denoting the total number of servers and a 2D 0-indexed integer array logs, where logs[i] = [server_id, time] denotes that the server with id server_id received a request at time time.
# You are also given an integer x and a 0-indexed integer array queries.
# Return a 0-indexed integer array arr of length queries.length where arr[i] represents the number of servers that did not receive any requests during the time interval [queries[i] - x, queries[i]].
# Note that the time intervals are inclusive.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countServers(self, n: int, logs: List[List[int]], x: int, queries: List[int]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def countServers(
#         self, n: int, logs: List[List[int]], x: int, queries: List[int]
#     ) -> List[int]:
#         cnt = Counter()
#         logs.sort(key=lambda x: x[1])
#         ans = [0] * len(queries)
#         j = k = 0
#         for r, i in sorted(zip(queries, count())):
#             l = r - x
#             while k < len(logs) and logs[k][1] <= r:
#                 cnt[logs[k][0]] += 1
#                 k += 1
#             while j < len(logs) and logs[j][1] < l:
#                 cnt[logs[j][0]] -= 1
#                 if cnt[logs[j][0]] == 0:
#                     cnt.pop(logs[j][0])
#                 j += 1
#             ans[i] = n - len(cnt)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Maintain a counter cnt of servers that have received requests. Maintain two
# pointers j and k, where j is the leftmost index of logs and k is the rightmost
# index of logs. Scan queries from left to right. For each query, move j and k
# rightward until the time interval [l, r] is covered. For each request in the
# interval, increment the counter of the server it belongs to. For each query,
# return n − len(cnt). Time O(n log n); space O(n).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 2.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findEvenMaximum(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findEvenMaximum(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 2 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 2. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 3.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 3 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 3. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 5.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 5 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 5. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 7.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 7 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 7. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 11.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 11 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 11. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 13.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:
#             ans.append(max(x for x in nums[l:r + 1] if x % 13 == 0))
#         return ans
#
# ## Explanation
#
# Scan queries from left to right. For each query, find the maximum value of
# nums[j] where lefti <= j <= righti and j is a multiple of 13. Time O(n + q);
# space O(1).
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, find the maximum value of nums[j] where lefti <= j <= righti and j is a multiple of 17.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def findMultiple(self, nums: List[int], queries: List[List[int]]) -> List[int]:
#         ans = []
#         for l, r in queries:

# %%
print(medium_ds[1]["completion"])
# Out:
# class Solution:
#     def countServers(
#         self, n: int, logs: List[List[int]], x: int, queries: List[int]
#     ) -> List[int]:
#         cnt = Counter()
#         logs.sort(key=lambda x: x[1])
#         ans = [0] * len(queries)
#         j = k = 0
#         for r, i in sorted(zip(queries, count())):
#             l = r - x
#             while k < len(logs) and logs[k][1] <= r:
#                 cnt[logs[k][0]] += 1
#                 k += 1
#             while j < len(logs) and logs[j][1] < l:
#                 cnt[logs[j][0]] -= 1
#                 if cnt[logs[j][0]] == 0:
#                     cnt.pop(logs[j][0])
#                 j += 1
#             ans[i] = n - len(cnt)
#         return ans

# %%
print(exp_m2)
# Out:
# ## Explanation
#
# Maintain a counter cnt of servers that have received requests. Maintain two
# pointers j and k, where j is the leftmost index of logs and k is the rightmost
# index of logs. Scan queries from left to right. For each query, move j and k
# rightward until the time interval [l, r] is covered. For each request in the
# interval, increment the counter of the server it belongs to. For each query,
# return n − len(cnt). Time O(n log n); space O(n).

# %% [markdown]
# #### m3

# %%
prompt_exp_m3 = make_prompt_explain(medium_ds[2], medium_ds[2]["completion"])
print(prompt_exp_m3)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums representing the initial positions of some marbles. You are also given two 0-indexed integer arrays moveFrom and moveTo of equal length.
# Throughout moveFrom.length steps, you will change the positions of the marbles. On the ith step, you will move all marbles at position moveFrom[i] to position moveTo[i].
# After completing all the steps, return the sorted list of occupied positions.
# Notes:
#
# We call a position occupied if there is at least one marble in that position.
# There may be multiple marbles in a single position.
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def relocateMarbles(
#         self, nums: List[int], moveFrom: List[int], moveTo: List[int]
#     ) -> List[int]:
#         pos = set(nums)
#         for f, t in zip(moveFrom, moveTo):
#             pos.remove(f)
#             pos.add(t)
#         return sorted(pos)
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_m3, exp_m3 = generate_explain(prompt_exp_m3)
print(raw_m3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed integer array nums representing the initial positions of some marbles. You are also given two 0-indexed integer arrays moveFrom and moveTo of equal length.
# Throughout moveFrom.length steps, you will change the positions of the marbles. On the ith step, you will move all marbles at position moveFrom[i] to position moveTo[i].
# After completing all the steps, return the sorted list of occupied positions.
# Notes:
#
# We call a position occupied if there is at least one marble in that position.
# There may be multiple marbles in a single position.
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def relocateMarbles(self, nums: List[int], moveFrom: List[int], moveTo: List[int]) -> List[int]:
# ```
# ## Solution
# class Solution:
#     def relocateMarbles(
#         self, nums: List[int], moveFrom: List[int], moveTo: List[int]
#     ) -> List[int]:
#         pos = set(nums)
#         for f, t in zip(moveFrom, moveTo):
#             pos.remove(f)
#             pos.add(t)
#         return sorted(pos)
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Use a set to track the occupied positions. For each move, remove the old
# position from the set and add the new position. Finally, sort the set. Overall
# complexity: O(n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The array nums is called beautiful if the following conditions are satisfied:
#
# nums.length is even.
# nums[i]!= nums[i + 1] for all 0 <= i < nums.length - 1.
# Return true if nums is beautiful, or false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautiful(self, nums: List[int]) -> bool:
#         return len(nums) % 2 == 0 and all(x!= y for x, y in zip(nums, nums[1:]))
#
# ## Explanation
#
# Check that the array is even-length and that the elements are distinct. Overall
# complexity: O(n) time and O(1) space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer

# %%
print(exp_m3)
# Out:
# ## Explanation
#
# Use a set to track the occupied positions. For each move, remove the old
# position from the set and add the new position. Finally, sort the set. Overall
# complexity: O(n) time and O(n) space.

# %% [markdown]
# #### m4

# %%
prompt_exp_m4 = make_prompt_explain(medium_ds[3], medium_ds[3]["completion"])
print(prompt_exp_m4)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given an integer n and a 0-indexed 2D array queries where queries[i] = [typei, indexi, vali].
# Initially, there is a 0-indexed n x n matrix filled with 0's. For each query, you must apply one of the following changes:
#
# if typei == 0, set the values in the row with indexi to vali, overwriting any previous values.
# if typei == 1, set the values in the column with indexi to vali, overwriting any previous values.
#
# Return the sum of integers in the matrix after all queries are applied.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
# ```
# ## Solution
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
#         row = set()
#         col = set()
#         ans = 0
#         for t, i, v in queries[::-1]:
#             if t == 0:
#                 if i not in row:
#                     ans += v * (n - len(col))
#                     row.add(i)
#             else:
#                 if i not in col:
#                     ans += v * (n - len(row))
#                     col.add(i)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_m4, exp_m4 = generate_explain(prompt_exp_m4)
print(raw_m4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given an integer n and a 0-indexed 2D array queries where queries[i] = [typei, indexi, vali].
# Initially, there is a 0-indexed n x n matrix filled with 0's. For each query, you must apply one of the following changes:
#
# if typei == 0, set the values in the row with indexi to vali, overwriting any previous values.
# if typei == 1, set the values in the column with indexi to vali, overwriting any previous values.
#
# Return the sum of integers in the matrix after all queries are applied.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
# ```
# ## Solution
# class Solution:
#     def matrixSumQueries(self, n: int, queries: List[List[int]]) -> int:
#         row = set()
#         col = set()
#         ans = 0
#         for t, i, v in queries[::-1]:
#             if t == 0:
#                 if i not in row:
#                     ans += v * (n - len(col))
#                     row.add(i)
#             else:
#                 if i not in col:
#                     ans += v * (n - len(row))
#                     col.add(i)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Maintain two sets, row and col, of indices that have been updated. For each
# query, if typei == 0, add vali to the answer. If typei == 1, add vali * (n −
# len(row)) to the answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed 2D integer array grid of size m x n.
# You are also given an integer k.
# You can perform the following operation any number of times:
# Choose any row in the grid and reverse it.
# Return the maximum possible sum of the values in the grid after performing the operation at most k times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, grid: List[List[int]], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, grid: List[List[int]], k: int) -> int:
#         n, m = len(grid), len(grid[0])
#         ans = 0
#         for i in range(n):
#             for j in range(m):
#                 ans += grid[i][j]
#         for _ in range(k):
#             mx = 0
#             for i in range(n):
#                 for j in range(m):
#                     grid[i][j] = -grid[i][j]
#                     mx = max(mx, grid[i][j])
#             for i in range(n):
#                 for j in range(m):
#                     grid[i][j] += mx
#         return sum(sum(row) for row in grid)
#
# ## Explanation
#
# For each operation, reverse the entire row. Then, for each row, find the
# largest value and subtract it from all values. This will make the row
# monotonic, and the largest sum will be the sum of the row minus the largest
# value.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed 2D integer array grid of size m x n.
# You are also given an integer k.
# You can perform the following operation any number of times:
# Choose any row in the grid and reverse it.
# Return the maximum possible sum of the values in the grid after performing the operation at most k times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSum(self, grid: List[List[int]], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumSum(self, grid: List[List[int]], k: int) -> int:
#         n, m = len(grid), len(grid[0])
#         ans = 0
#         for i in range(n):
#             for j in range(m):
#                 ans += grid[i][j]
#         for _ in range(k):
#             mx = 0
#             for i in range(n):
#                 for j in range(m):
#                     grid[i][j] = -grid[i][j]
#                     mx = max(mx, grid[i][j])
#             for i in range(n):
#                 for j in range(m):
#                     grid[i][j] += mx
#         return sum(sum(row) for row in grid)
# <file_sep><fim_prefix><fim_suffix>
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You can perform the following operation on s any number of times:
# Choose any substring of s and reverse it.
# Return the maximum possible length of a substring of s that can be made
# palindromic after performing the above operation any number of times.
# A substring is a contiguous sequence of characters within a string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestPalindrome(self, s: str) -> int:
# ```
# ## Solution
# class Solution:
#     def longestPalindrome(self, s: str) -> int:
#         ans = 0
#         for i in range(len(s)):
#             for j in range(i + 1, len(s) + 1):
#                 if s[i:j] == s[i:j][::-1]:
#                     ans = max(ans, j - i)
#         return ans
#
# ## Explanation
#
# For each substring of s, check whether it is a palindrome.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.
# Reverse the substring.
# Return the resulting string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
# ```
# ## Solution
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
#         return s[:left] + s[left:right + 1][::-1] + s[right + 1 :]
#
# ## Explanation
#
# Reverse the substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.
# Reverse the substring.
# Return the resulting string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
# ```
# ## Solution
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
#         return s[:left] + s[left:right + 1][::-1] + s[right + 1 :]
#
# ## Explanation
#
# Reverse the substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.
# Reverse the substring.
# Return the resulting string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
# ```
# ## Solution
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
#         return s[:left] + s[left:right + 1][::-1] + s[right + 1 :]
#
# ## Explanation
#
# Reverse the substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.
# Reverse the substring.
# Return the resulting string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
# ```
# ## Solution
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
#         return s[:left] + s[left:right + 1][::-1] + s[right + 1 :]
#
# ## Explanation
#
# Reverse the substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.
# Reverse the substring.
# Return the resulting string.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
# ```
# ## Solution
# class Solution:
#     def reverseString(self, s: str, left: int, right: int) -> str:
#         return s[:left] + s[left:right + 1][::-1] + s[right + 1 :]
#
# ## Explanation
#
# Reverse the substring.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# You are also given a 0-indexed 2D integer array queries where queries[i] = [lefti, righti].
# For each query, you must perform the following steps:
# Choose a substring of s from lefti to righti inclusive.

# %%
print(exp_m4)
# Out:
# ## Explanation
#
# Maintain two sets, row and col, of indices that have been updated. For each
# query, if typei == 0, add vali to the answer. If typei == 1, add vali * (n −
# len(row)) to the answer.

# %% [markdown]
# #### m5

# %%
prompt_exp_m5 = make_prompt_explain(medium_ds[4], medium_ds[4]["completion"])
print(prompt_exp_m5)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a positive integer array nums.
# Partition nums into two arrays, nums1 and nums2, such that:
#
# Each element of the array nums belongs to either the array nums1 or the array nums2.
# Both arrays are non-empty.
# The value of the partition is minimized.
#
# The value of the partition is |max(nums1) - min(nums2)|.
# Here, max(nums1) denotes the maximum element of the array nums1, and min(nums2) denotes the minimum element of the array nums2.
# Return the integer denoting the value of such partition.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return min(b - a for a, b in pairwise(nums))
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_m5, exp_m5 = generate_explain(prompt_exp_m5)
print(raw_m5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a positive integer array nums.
# Partition nums into two arrays, nums1 and nums2, such that:
#
# Each element of the array nums belongs to either the array nums1 or the array nums2.
# Both arrays are non-empty.
# The value of the partition is minimized.
#
# The value of the partition is |max(nums1) - min(nums2)|.
# Here, max(nums1) denotes the maximum element of the array nums1, and min(nums2) denotes the minimum element of the array nums2.
# Return the integer denoting the value of such partition.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def findValueOfPartition(self, nums: List[int]) -> int:
#         nums.sort()
#         return min(b - a for a, b in pairwise(nums))
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Sort the array. The answer is the minimum of the differences between adjacent
# elements.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose two indices i and j such that 0 <= i < j < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[j].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValue(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValue(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the operation any number of
# times.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumValueAfterInsertion(self, nums: List[int]) -> int:
#         return max(accumulate(nums))
#
# ## Explanation
#
# Compute the cumulative sum of the array. The answer is the maximum of these
# sums.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# You can perform the following operation on nums any number of times:
#
# Choose an index i such that 0 <= i < nums.length.
# Replace nums[i] with the sum of nums[i] and nums[i + 1].
# Return the maximum value of nums after performing the

# %%
print(exp_m5)
# Out:
# ## Explanation
#
# Sort the array. The answer is the minimum of the differences between adjacent
# elements.

# %% [markdown]
# #### h2

# %%
prompt_exp_h2 = make_prompt_explain(hard_ds[1], hard_ds[1]["completion"])
print(prompt_exp_h2)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Given a 0-indexed integer array nums, return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
# ## Solution
# from sortedcontainers import SortedList
#
#
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             sl = SortedList()
#             cnt = 0
#             for j in range(i, n):
#                 k = sl.bisect_left(nums[j])
#                 h = k - 1
#                 if h >= 0 and nums[j] - sl[h] > 1:
#                     cnt += 1
#                 if k < len(sl) and sl[k] - nums[j] > 1:
#                     cnt += 1
#                 if h >= 0 and k < len(sl) and sl[k] - sl[h] > 1:
#                     cnt -= 1
#                 sl.add(nums[j])
#                 ans += cnt
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_h2, exp_h2 = generate_explain(prompt_exp_h2)
print(raw_h2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# The imbalance number of a 0-indexed integer array arr of length n is defined as the number of indices in sarr = sorted(arr) such that:
#
# 0 <= i < n - 1, and
# sarr[i+1] - sarr[i] > 1
#
# Here, sorted(arr) is the function that returns the sorted version of arr.
# Given a 0-indexed integer array nums, return the sum of imbalance numbers of all its subarrays.
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
# ```
# ## Solution
# from sortedcontainers import SortedList
#
#
# class Solution:
#     def sumImbalanceNumbers(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             sl = SortedList()
#             cnt = 0
#             for j in range(i, n):
#                 k = sl.bisect_left(nums[j])
#                 h = k - 1
#                 if h >= 0 and nums[j] - sl[h] > 1:
#                     cnt += 1
#                 if k < len(sl) and sl[k] - nums[j] > 1:
#                     cnt += 1
#                 if h >= 0 and k < len(sl) and sl[k] - sl[h] > 1:
#                     cnt -= 1
#                 sl.add(nums[j])
#                 ans += cnt
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# For each i, compute the number of imbalance numbers in the subarray [i, n − 1].
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The score of nums is defined as the number of indices i for which nums[i] is even.
# Return the maximum score of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans += 1
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans = max(ans, i + 1 + n - i - 1)
#         return ans
#
# ## Explanation
#
# For each even number, count the number of indices that are greater than it.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The score of nums is defined as the number of indices i for which nums[i] is even.
# Return the maximum score of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans += 1
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans = max(ans, i + 1 + n - i - 1)
#         return ans
#
# ## Explanation
#
# For each even number, count the number of indices that are greater than it.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The score of nums is defined as the number of indices i for which nums[i] is even.
# Return the maximum score of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def maximumScore(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans += 1
#         for i in range(n):
#             if nums[i] % 2 == 0:
#                 ans = max(ans, i + 1 + n - i - 1)
#         return ans
# <file_sep><fim_prefix><fim_suffix>e:
#             return 0
#         return 1 + self.dfs(root.left, val) + self.dfs(root.right, val)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(root.right)
#
#
# class Solution:
#     def countNodes(self, root: Optional[TreeNode]) -> int:
#         if not root:
#             return 0
#         return 1 + self.countNodes(root.left) + self.countNodes(

# %%
print(exp_h2)
# Out:
# ## Explanation
#
# For each i, compute the number of imbalance numbers in the subarray [i, n − 1].

# %% [markdown]
# #### h3

# %%
prompt_exp_h3 = make_prompt_explain(hard_ds[2], hard_ds[2]["completion"])
print(prompt_exp_h3)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# Given a string s and an integer k, partition s into k substrings such that the letter changes needed to make each substring a semi-palindrome are minimized.
# Return the minimum number of letter changes required.
# A semi-palindrome is a special type of string that can be divided into palindromes based on a repeating pattern. To check if a string is a semi-palindrome:​
#
# Choose a positive divisor d of the string's length. d can range from 1 up to, but not including, the string's length. For a string of length 1, it does not have a valid divisor as per this definition, since the only divisor is its length, which is not allowed.
# For a given divisor d, divide the string into groups where each group contains characters from the string that follow a repeating pattern of length d. Specifically, the first group consists of characters at positions 1, 1 + d, 1 + 2d, and so on; the second group includes characters at positions 2, 2 + d, 2 + 2d, etc.
# The string is considered a semi-palindrome if each of these groups forms a palindrome.
#
# Consider the string "abcabc":
#
# The length of "abcabc" is 6. Valid divisors are 1, 2, and 3.
# For d = 1: The entire string "abcabc" forms one group. Not a palindrome.
# For d = 2:
#
# Group 1 (positions 1, 3, 5): "acb"
# Group 2 (positions 2, 4, 6): "bac"
# Neither group forms a palindrome.
#
#
# For d = 3:
#
# Group 1 (positions 1, 4): "aa"
# Group 2 (positions 2, 5): "bb"
# Group 3 (positions 3, 6): "cc"
# All groups form palindromes. Therefore, "abcabc" is a semi-palindrome.
#
#
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
#         n = len(s)
#         g = [[inf] * (n + 1) for _ in range(n + 1)]
#         for i in range(1, n + 1):
#             for j in range(i, n + 1):
#                 m = j - i + 1
#                 for d in range(1, m):
#                     if m % d == 0:
#                         cnt = 0
#                         for l in range(m):
#                             r = (m // d - 1 - l // d) * d + l % d
#                             if l >= r:
#                                 break
#                             if s[i - 1 + l] != s[i - 1 + r]:
#                                 cnt += 1
#                         g[i][j] = min(g[i][j], cnt)
#
#         f = [[inf] * (k + 1) for _ in range(n + 1)]
#         f[0][0] = 0
#         for i in range(1, n + 1):
#             for j in range(1, k + 1):
#                 for h in range(i - 1):
#                     f[i][j] = min(f[i][j], f[h][j - 1] + g[h + 1][i])
#         return f[n][k]
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_h3, exp_h3 = generate_explain(prompt_exp_h3)
print(raw_h3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# Given a string s and an integer k, partition s into k substrings such that the letter changes needed to make each substring a semi-palindrome are minimized.
# Return the minimum number of letter changes required.
# A semi-palindrome is a special type of string that can be divided into palindromes based on a repeating pattern. To check if a string is a semi-palindrome:​
#
# Choose a positive divisor d of the string's length. d can range from 1 up to, but not including, the string's length. For a string of length 1, it does not have a valid divisor as per this definition, since the only divisor is its length, which is not allowed.
# For a given divisor d, divide the string into groups where each group contains characters from the string that follow a repeating pattern of length d. Specifically, the first group consists of characters at positions 1, 1 + d, 1 + 2d, and so on; the second group includes characters at positions 2, 2 + d, 2 + 2d, etc.
# The string is considered a semi-palindrome if each of these groups forms a palindrome.
#
# Consider the string "abcabc":
#
# The length of "abcabc" is 6. Valid divisors are 1, 2, and 3.
# For d = 1: The entire string "abcabc" forms one group. Not a palindrome.
# For d = 2:
#
# Group 1 (positions 1, 3, 5): "acb"
# Group 2 (positions 2, 4, 6): "bac"
# Neither group forms a palindrome.
#
#
# For d = 3:
#
# Group 1 (positions 1, 4): "aa"
# Group 2 (positions 2, 5): "bb"
# Group 3 (positions 3, 6): "cc"
# All groups form palindromes. Therefore, "abcabc" is a semi-palindrome.
#
#
#
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
#         n = len(s)
#         g = [[inf] * (n + 1) for _ in range(n + 1)]
#         for i in range(1, n + 1):
#             for j in range(i, n + 1):
#                 m = j - i + 1
#                 for d in range(1, m):
#                     if m % d == 0:
#                         cnt = 0
#                         for l in range(m):
#                             r = (m // d - 1 - l // d) * d + l % d
#                             if l >= r:
#                                 break
#                             if s[i - 1 + l]!= s[i - 1 + r]:
#                                 cnt += 1
#                         g[i][j] = min(g[i][j], cnt)
#
#         f = [[inf] * (k + 1) for _ in range(n + 1)]
#         f[0][0] = 0
#         for i in range(1, n + 1):
#             for j in range(1, k + 1):
#                 for h in range(i - 1):
#                     f[i][j] = min(f[i][j], f[h][j - 1] + g[h + 1][i])
#         return f[n][k]
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring

# %%
print(exp_h3)
# Out:
# ## Explanation
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring s[i:j] a semi-palindrome.
#
# For each substring of length n, we can divide it into n groups of length 1, 2,..., n. For each group, we can check if it forms a semi-palindrome.
#
# Let g[i][j] be the minimum number of changes needed to make the substring

# %% [markdown]
# #### h4

# %%
prompt_exp_h4 = make_prompt_explain(hard_ds[3], hard_ds[3]["completion"])
print(prompt_exp_h4)
# Out:
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         s = set(forbidden)
#         ans = i = 0
#         for j in range(len(word)):
#             for k in range(j, max(j - 10, i - 1), -1):
#                 if word[k : j + 1] in s:
#                     i = k + 1
#                     break
#             ans = max(ans, j - i + 1)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>

# %%
raw_h4, exp_h4 = generate_explain(prompt_exp_h4)
print(raw_h4)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a string word and an array of strings forbidden.
# A string is called valid if none of its substrings are present in forbidden.
# Return the length of the longest valid substring of the string word.
# A substring is a contiguous sequence of characters in a string, possibly empty.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
# ```
# ## Solution
# class Solution:
#     def longestValidSubstring(self, word: str, forbidden: List[str]) -> int:
#         s = set(forbidden)
#         ans = i = 0
#         for j in range(len(word)):
#             for k in range(j, max(j - 10, i - 1), -1):
#                 if word[k : j + 1] in s:
#                     i = k + 1
#                     break
#             ans = max(ans, j - i + 1)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Maintain a sliding window [i, j] such that the substring word[i:j + 1] is
# valid. For each j, binary-search the leftmost i such that word[i:j + 1] is
# valid. The answer is the maximum of all j - i + 1.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string is called good if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in the string is equal to the number of occurrences of the letter 'b' in the string.
# The number of occurrences of the letter 'b' in the string is equal to the number of occurrences of the letter 'c' in the string.
# The number of occurrences of the letter 'c' in the string is equal to the number of occurrences of the letter 'a' in the string.
# Return the number of good strings that can be formed from s. Since the answer may be very large, return it modulo 109 + 7.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
# ```
# ## Solution
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
#         MOD = 10 ** 9 + 7
#         dp = [0] * (high + 1)
#         dp[0] = 1
#         for i in range(1, high + 1):
#             if i >= low:
#                 dp[i] += dp[i - low]
#             if i >= one:
#                 dp[i] += dp[i - one]
#             if i >= two:
#                 dp[i] += dp[i - two]
#             dp[i] %= MOD
#         return sum(dp[low:high + 1]) % MOD
#
# ## Explanation
#
# Let dp[i] be the number of good strings of length i. We can compute dp[i]
# using a sliding window of length 3. For each i, we can add the number of good
# strings of length i - 1, i - low, i - one, and i - two.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string is called good if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in the string is equal to the number of occurrences of the letter 'b' in the string.
# The number of occurrences of the letter 'b' in the string is equal to the number of occurrences of the letter 'c' in the string.
# The number of occurrences of the letter 'c' in the string is equal to the number of occurrences of the letter 'a' in the string.
# Return the number of good strings that can be formed from s. Since the answer may be very large, return it modulo 109 + 7.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
# ```
# ## Solution
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
#         MOD = 10 ** 9 + 7
#         dp = [0] * (high + 1)
#         dp[0] = 1
#         for i in range(1, high + 1):
#             if i >= low:
#                 dp[i] += dp[i - low]
#             if i >= one:
#                 dp[i] += dp[i - one]
#             if i >= two:
#                 dp[i] += dp[i - two]
#             dp[i] %= MOD
#         return sum(dp[low:high + 1]) % MOD
#
# ## Explanation
#
# Let dp[i] be the number of good strings of length i. We can compute dp[i]
# using a sliding window of length 3. For each i, we can add the number of good
# strings of length i - 1, i - low, i - one, and i - two.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string is called good if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in the string is equal to the number of occurrences of the letter 'b' in the string.
# The number of occurrences of the letter 'b' in the string is equal to the number of occurrences of the letter 'c' in the string.
# The number of occurrences of the letter 'c' in the string is equal to the number of occurrences of the letter 'a' in the string.
# Return the number of good strings that can be formed from s. Since the answer may be very large, return it modulo 109 + 7.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
# ```
# ## Solution
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
#         MOD = 10 ** 9 + 7
#         dp = [0] * (high + 1)
#         dp[0] = 1
#         for i in range(1, high + 1):
#             if i >= low:
#                 dp[i] += dp[i - low]
#             if i >= one:
#                 dp[i] += dp[i - one]
#             if i >= two:
#                 dp[i] += dp[i - two]
#             dp[i] %= MOD
#         return sum(dp[low:high + 1]) % MOD
#
# ## Explanation
#
# Let dp[i] be the number of good strings of length i. We can compute dp[i]
# using a sliding window of length 3. For each i, we can add the number of good
# strings of length i - 1, i - low, i - one, and i - two.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string is called good if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in the string is equal to the number of occurrences of the letter 'b' in the string.
# The number of occurrences of the letter 'b' in the string is equal to the number of occurrences of the letter 'c' in the string.
# The number of occurrences of the letter 'c' in the string is equal to the number of occurrences of the letter 'a' in the string.
# Return the number of good strings that can be formed from s. Since the answer may be very large, return it modulo 109 + 7.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
# ```
# ## Solution
# class Solution:
#     def countGoodStrings(self, low: int, high: int, zero: int, one: int, two: int) -> int:
#         MOD = 10 ** 9 + 7
#         dp = [0] * (high + 1)
#         dp[0] = 1
#         for i in range(1, high + 1):
#             if i >= low:
#                 dp[i] += dp[i - low]
#             if i >= one:
#                 dp[i] += dp[i - one]
#             if i >= two:
#                 dp[i] += dp[i - two]
#             dp[i] %= MOD
#         return sum(dp[low:high + 1]) % MOD
#
# ## Explanation
#
# Let dp[i] be the number of good strings of length i. We can compute dp[i]
# using a sliding window of length 3. For each i, we can add the number of good
# strings of length i - 1, i - low, i - one, and i - two.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# A string is called good if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in the string is equal to the number of occurrences of the letter 'b' in the string.
# The number of occurrences of the letter 'b' in the string is equal to the number of occurrences of the letter 'c' in the string.
# The number of occurrences of the letter 'c' in the string is equal to the number of occurrences of the letter 'a' in the string.
# Return the number of good strings that can be formed from s. Since the answer may be very large, return it modulo 109 + 7.
#
# Please complete the following python code precisely

# %%
print(exp_h4)
# Out:
# ## Explanation
#
# Maintain a sliding window [i, j] such that the substring word[i:j + 1] is
# valid. For each j, binary-search the leftmost i such that word[i:j + 1] is
# valid. The answer is the maximum of all j - i + 1.

# %% [markdown]
# #### h5

# %%
prompt_exp_h5 = make_prompt_explain(hard_ds[4], hard_ds[4]["completion"])
print(prompt_exp_h5)

# %%
raw_h5, exp_h5 = generate_explain(prompt_exp_h5)
print(raw_h5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# <start>
# ## Task
# You are given a 1-indexed integer array nums of length n.
# An element nums[i] of nums is called special if i divides n, i.e. n % i == 0.
# Return the sum of the squares of all special elements of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def sumOfSquares(self, nums: List[int]) -> int:
#         n = len(nums)
#         return sum(x * x for i, x in enumerate(nums, 1) if n % i == 0)
#
# ## Explanation
#
# Compute n = len(nums). Scan the array with 1-based indices. Whenever an index i
# divides n, that element is “special”; square it and accumulate. The one-liner
# uses a comprehension, giving O(n) time and O(1) extra space.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums and an integer k.
# A subarray is called equal if all of its elements are equal. Note that the empty subarray is an equal subarray.
# Return the length of the longest possible equal subarray after deleting at most k elements from nums.
# A subarray is a contiguous, possibly empty sequence of elements within an array.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def longestEqualSubarray(self, nums: List[int], k: int) -> int:
#         cnt = Counter()
#         l = 0
#         mx = 0
#         for r, x in enumerate(nums):
#             cnt[x] += 1
#             mx = max(mx, cnt[x])
#             if r - l + 1 - mx > k:
#                 cnt[nums[l]] -= 1
#                 l += 1
#         return mx
#
# ## Explanation
#
# Slide a window [l, r] while counting element frequencies. Keep mx, the highest
# frequency inside the window. If window_size − mx > k (too many deletions
# needed), move l right and update counts until the window is feasible. The
# largest mx seen is the answer. Time O(n); space O(u) where u is the number of
# distinct values in the window.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given two 0-indexed integer arrays nums1 and nums2, each of length n, and a 1-indexed 2D array queries where queries[i] = [xi, yi].
# For the ith query, find the maximum value of nums1[j] + nums2[j] among all indices j (0 <= j < n), where nums1[j] >= xi and nums2[j] >= yi, or -1 if there is no j satisfying the constraints.
# Return an array answer where answer[i] is the answer to the ith query.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def maximumSumQueries(self, nums1: List[int], nums2: List[int], queries: List[List[int]]) -> List[int]:
# ```
# ## Solution
# class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n = n
#         self.c = [-1] * (n + 1)
#
#     def update(self, x: int, v: int):
#         while x <= self.n:
#             self.c[x] = max(self.c[x], v)
#             x += x & -x
#
#     def query(self, x: int) -> int:
#         mx = -1
#         while x:
#             mx = max(mx, self.c[x])
#             x -= x & -x
#         return mx
#
#
# class Solution:
#     def maximumSumQueries(
#         self, nums1: List[int], nums2: List[int], queries: List[List[int]]
#     ) -> List[int]:
#         nums = sorted(zip(nums1, nums2), key=lambda x: -x[0])
#         nums2.sort()
#         n, m = len(nums1), len(queries)
#         ans = [-1] * m
#         j = 0
#         tree = BinaryIndexedTree(n)
#         for i in sorted(range(m), key=lambda i: -queries[i][0]):
#             x, y = queries[i]
#             while j < n and nums[j][0] >= x:
#                 k = n - bisect_left(nums2, nums[j][1])
#                 tree.update(k, nums[j][0] + nums[j][1])
#                 j += 1
#             k = n - bisect_left(nums2, y)
#             ans[i] = tree.query(k)
#         return ans
#
# ## Explanation
#
# Process queries offline. Sort data pairs (nums1, nums2) in descending nums1
# order; sort queries in descending xi order. Sweep: for each xi, insert all
# points with nums1 ≥ xi into a Fenwick tree keyed by compressed nums2, storing
# max(nums1 + nums2). For a query [xi, yi], binary-search the first compressed
# index with nums2 ≥ yi and read the tree’s prefix maximum. Overall complexity:
# O((n + q) log n) time and O(n) space.
#
# <end>
#
#
#
# <start>
# <fim_prefix>
# ## Task
# You are given a 0-indexed 2D integer array items of length n and an integer k.
# items[i] = [profiti, categoryi], where profiti and categoryi denote the profit and category of the ith item respectively.
# Let's define the elegance of a subsequence of items as total_profit + distinct_categories2, where total_profit is the sum of all profits in the subsequence, and distinct_categories is the number of distinct categories from all the categories in the selected subsequence.
# Your task is to find the maximum elegance from all subsequences of size k in items.
# Return an integer denoting the maximum elegance of a subsequence of items with size exactly k.
# Note: A subsequence of an array is a new array generated from the original array by deleting some elements (possibly none) without changing the remaining elements' relative order.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
# ```
# ## Solution
# class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         items.sort(key=lambda x: -x[0])
#         tot = 0
#         vis = set()
#         dup = []
#         for p, c in items[:k]:
#             tot += p
#             if c not in vis:
#                 vis.add(c)
#             else:
#                 dup.append(p)
#         ans = tot + len(vis) ** 2
#         for p, c in items[k:]:
#             if c in vis or not dup:
#                 continue
#             vis.add(c)
#             tot += p - dup.pop()
#             ans = max(ans, tot + len(vis) ** 2)
#         return ans
#
# <fim_suffix>
# ## Explanation
# <fim_middle>## Explanation
#
# Sort items by profit in descending order. Maintain a total profit tot and a set
# of categories vis. For each item, update tot and vis. If the category of the
# item is not in vis, add it to vis. Otherwise, add the profit of the item to
# dup. Maintain a variable ans, the maximum elegance so far. For each item, if
# the category is not in vis and dup is not empty, add the category to vis and
# remove the profit of the last item in dup. Update ans. Return ans.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed integer array nums.
# The score of nums is defined as the number of indices i for which nums[i] is
# greater than all the elements to its left, and less than all the elements to its
# right.
# Return the score of nums.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def countScore(self, nums: List[int]) -> int:
# ```
# ## Solution
# class Solution:
#     def countScore(self, nums: List[int]) -> int:
#         n = len(nums)
#         ans = 0
#         for i in range(n):
#             l = 0
#             r = 0
#             for j in range(i):
#                 if nums[j] < nums[i]:
#                     l += 1
#             for j in range(i + 1, n):
#                 if nums[j] < nums[i]:
#                     r += 1
#             ans += l * r
#         return ans
#
# ## Explanation
#
# For each index i, count the number of indices j to the left of i and the number
# of indices j to the right of i. Multiply these two numbers and add to the
# answer.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. If the number of occurrences of
# each letter is not equal to the number of occurrences of the letter’s
# uppercase counterpart, return False.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. If the number of occurrences of
# each letter is not equal to the number of occurrences of the letter’s
# uppercase counterpart, return False.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. If the number of occurrences of
# each letter is not equal to the number of occurrences of the letter’s
# uppercase counterpart, return False.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. If the number of occurrences of
# each letter is not equal to the number of occurrences of the letter’s
# uppercase counterpart, return False.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase()]:
#                 return False
#         return True
#
# ## Explanation
#
# Count the number of occurrences of each letter. If the number of occurrences of
# each letter is not equal to the number of occurrences of the letter’s
# uppercase counterpart, return False.
#
# <end>
#
#
#
# <start>
# ## Task
# You are given a 0-indexed string s.
# The string s is called beautiful if it satisfies the following conditions:
# The number of occurrences of the letter 'a' in s is equal to the number of
# occurrences of the letter 'b' in s.
# The number of occurrences of the letter 'b' in s is equal to the number of
# occurrences of the letter 'c' in s.
# The number of occurrences of the letter 'c' in s is equal to the number of
# occurrences of the letter 'a' in s.
# Return true if s is beautiful, and false otherwise.
#
# Please complete the following python code precisely:
# ```python
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
# ```
# ## Solution
# class Solution:
#     def isBeautifulString(self, s: str) -> bool:
#         cnt = Counter(s)
#         for c in "abc":
#             if cnt[c]!= cnt[c.swapcase

# %%
print(exp_h5)
# Out:
# ## Explanation
#
# Sort items by profit in descending order. Maintain a total profit tot and a set
# of categories vis. For each item, update tot and vis. If the category of the
# item is not in vis, add it to vis. Otherwise, add the profit of the item to
# dup. Maintain a variable ans, the maximum elegance so far. For each item, if
# the category is not in vis and dup is not empty, add the category to vis and
# remove the profit of the last item in dup. Update ans. Return ans.
